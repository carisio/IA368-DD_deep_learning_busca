# %% [markdown]
# # Aula 8 - Solução dos exercícios - Parte 1 - Geração de queries
#
# Leandro Carísio Fernandes
#
# <br>
#
# Objetivo: gerar dataset para treino de modelos de buscas usando a técnica do InPars e avaliar um modelo reranqueador treinado neste dataset no TREC-COVID:
#
#     - Entrada: 3-5 exemplos few-shot + documento amostrado da coleção do TREC-COVID
#     - Saída: query que seja relevante para o documento amostrado
#     - É opcional fazer a etapa de filtragem usando as queries de maior prob descrita no Artigo.
#     - Como modelo gerador, use um dos seguintes modelos:
#         - ChatGPT-3.5-turbo: ~1 USD para cada 1k exemplos
#         - FLAN-T5 (base, large ou XL), LLAMA-(7,13B), Alpaca-(7/13B), que são possiveis de rodar no Colab Pro.
#         - Também tem a inference-api da HF: https://huggingface.co/inference-api.
#         - Com exceção do LLAMA, é possivel usar zero-shot ao inves de few-shot.
#     - Dado 1k-10k pares <query sintética; documento>, treinar um modelo reranqueador miniLM igual ao da aula 2/3.
#     - Exemplos negativos (i.e., <query sintética; doc não relevant) vem do BM25: dado a query sintetica, retornar top 1000 com o BM25, e amostrar aleatoriamente alguns documentos como negativo
#     - Começar treino do miniLM já treinado no MS MARCO
#
# Avaliar no TREC-COVID e comparar com o reranqueador apenas treinado no MSMARCO
#
# Nota: Também usar o dataset dos colegas para obter diversidade de exemplos: Assim que tiver gerado o dataset sintético, favor colocar na planilha, assim outras pessoas podem usa-lo.
#
#     - Para aumentar a aleatoriedade, seed usada deve o seu numero na planilha.
#
# Colocar dataset no formato jsonlines:
# {"query": query, "positive_doc_id": doc_id, "negative_doc_ids": [opcional]}\n

# %% [markdown]
# ## Gera os exemplos positivos

# %%
# %%time

url_trec_covid = 'https://public.ukp.informatik.tu-darmstadt.de/thakur/BEIR/datasets/trec-covid.zip'


# !pip install openai -q
# !pip install wget -q
# !pip install -qU huggingface_hub datasets
# Out:
# CPU times: total: 0 ns
# Wall time: 12.2 s

# %%
# %%time
from pathlib import Path
import wget
import json
import zipfile

    
if not Path('./collections/trec-covid.zip').is_file():
    # !mkdir collections
    wget.download(url_trec_covid, out='./collections/')
    with zipfile.ZipFile('./collections/trec-covid.zip', 'r') as zip_ref:
        zip_ref.extractall('./collections/')

    
def carrega_corpus_trec_covid():
    retorno = []
    with open('./collections/trec-covid/corpus.jsonl') as corpus:
        for i, line in enumerate(corpus):
            doc = json.loads(line)
            retorno.append( doc )
            if (i % 10000 == 0):
                print(f'Processado {i} documentos')
    return retorno

corpus_trec_covid = carrega_corpus_trec_covid()
# Out:
# Processado 0 documentos
# Processado 10000 documentos
# Processado 20000 documentos
# Processado 30000 documentos
# Processado 40000 documentos
# Processado 50000 documentos
# Processado 60000 documentos
# Processado 70000 documentos
# Processado 80000 documentos
# Processado 90000 documentos
# Processado 100000 documentos
# Processado 110000 documentos
# Processado 120000 documentos
# Processado 130000 documentos
# Processado 140000 documentos
# Processado 150000 documentos
# Processado 160000 documentos
# Processado 170000 documentos
# CPU times: total: 1.84 s
# Wall time: 2.38 s

# %%
import os
import openai

openai.api_key = os.getenv('API_KEY_OPENAI')

def adiciona_query_gpt_no_doc(idx):
    texto = corpus_trec_covid[idx]['text']

    msg = f"Formulate ONE query for the following passage. \
            Consider how a human use a search engine. Randomly choose if your question starts with what, how, why or which. \
            \n\n\
            {texto}"

    response = openai.ChatCompletion.create(model="gpt-3.5-turbo",
                messages=[
                    {"role": "system", "content": "You're cataloging documents and need to associate queries with document passages."},
                    {"role": "user", "content": msg}
                ],
                temperature=0,
                max_tokens=500)

    corpus_trec_covid[idx]['query'] = response['choices'][0]['message']['content']

    
def adiciona_query_no_corpus(nome_arquivo, indices):
    with open(nome_arquivo, 'a', encoding='utf-8') as arquivo:
        for i, idx in enumerate(indices):
            adiciona_query_gpt_no_doc(idx)
            
            doc = {"positive_doc_id": corpus_trec_covid[idx]["_id"], "query": corpus_trec_covid[idx]['query']}
            
            arquivo.write(f"{json.dumps(doc)}\n")
            
            if i % 20 == 0:
                print(f'{i} documentos processados')

# %%
import numpy as np

np.random.seed(8)

indices_candidatos = np.random.randint(0, high=len(corpus_trec_covid)-1, size=2000)
indices = [i for i in indices_candidatos if len(corpus_trec_covid[i]['text']) > 300]
indices = indices[0:1000]

# %%
#adiciona_query_no_corpus('leandro_carisio_20230428_01.jsonl', indices[600:])
# Out:
# 0 documentos processados
# 20 documentos processados
# 40 documentos processados
# 60 documentos processados
# 80 documentos processados
# 100 documentos processados
# 120 documentos processados
# 140 documentos processados
# 160 documentos processados
# 180 documentos processados
# 200 documentos processados
# 220 documentos processados
# 240 documentos processados
# 260 documentos processados
# 280 documentos processados
# 300 documentos processados
# 320 documentos processados
# 340 documentos processados
# 360 documentos processados
# 380 documentos processados

# %%
#adiciona_query_no_corpus('leandro_carisio_20230428_01.jsonl', indices)
# Out:
# 0 documentos processados

# %% [markdown]
# ## Testa leitura do Dataset no repositório

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import datasets
ds = datasets.load_dataset('unicamp-dl/trec-covid-experiment')
# Out:
# Downloading builder script:   0%|          | 0.00/2.18k [00:00<?, ?B/s]
# Downloading and preparing dataset trec-covid-experiment/default to C:/Users/caris/.cache/huggingface/datasets/unicamp-dl___trec-covid-experiment/default/0.0.0/39177de766cb7ace6cb0b5a27f1db36700b181fd775fbd271589004af3109267...
# Downloading data files:   0%|          | 0/11 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/255k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/152k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/311k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/627k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/280k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/307k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/238k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/237k [00:00<?, ?B/s]
# Generating example split: 0 examples [00:00, ? examples/s]
# Generating example2 split: 0 examples [00:00, ? examples/s]
# Generating eduseiti_100_queries_expansion_20230501_01 split: 0 examples [00:00, ? examples/s]
# Generating leandro_carisio_01 split: 0 examples [00:00, ? examples/s]
# Generating thales_1k_generated_queries_20230429 split: 0 examples [00:00, ? examples/s]
# Generating manoel_1k_generated_queries_20230430 split: 0 examples [00:00, ? examples/s]
# Generating manoel_2k_generated_queries_20230501 split: 0 examples [00:00, ? examples/s]
# Generating thiago_laitz_1k_queries split: 0 examples [00:00, ? examples/s]
# Generating mirelle_1k_generated_queries_20230501 split: 0 examples [00:00, ? examples/s]
# Generating hugo_padovani_query_generation split: 0 examples [00:00, ? examples/s]
# Generating marcus_borela_1k_gptj6b_20230501 split: 0 examples [00:00, ? examples/s]
# Dataset trec-covid-experiment downloaded and prepared to C:/Users/caris/.cache/huggingface/datasets/unicamp-dl___trec-covid-experiment/default/0.0.0/39177de766cb7ace6cb0b5a27f1db36700b181fd775fbd271589004af3109267. Subsequent calls will reuse this data.
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
import pandas as pd

# %%
df = pd.concat((v.to_pandas().assign(origin=k) for k,v in ds.items()),
               ignore_index=True)
df
# Out:
#                                                   query positive_doc_id  \
# 0                             This is a example query 1            doc1
# 1                         This is another example query            doc2
# 2             Example of query with no negative doc_ids            doc2
# 3                    This is a example query 1 (file 2)        doc12222
# 4                This is another example query (file 2)        doc12345
# ...                                                 ...             ...
# 9443  What is the significance of the phylogeny of t...        28nv3b8a
# 9444  What is the significance of the accuracy of th...        sffuejo1
# 9445  What is the significance of the low fecundity ...        3dyatdlv
# 9446  What is the significance of regional and natio...        jps1j60a
# 9447  What is the significance of the use of small m...        oa3x63xd
#
#                                        negative_doc_ids  \
# 0                                       [xxx, yyy, zzz]
# 1                                       [aaa, bbb, ccc]
# 2                                                    []
# 3                                       [xxx, yyy, zzz]
# 4                                       [aaa, bbb, ccc]
# ...                                                 ...
# 9443  [0sedbv51, m8lrc4c0, i6puqauk, bp8dqis1, exlsn...
# 9444  [go4d8jwn, n5gk1xhb, edunzo0f, xk2a7tsw, 6l888...
# 9445  [azv9yw9n, r55fe25x, wc23tqv2, vqmqnipq, d0dni...
# 9446  [uu4k2j2a, mo4luyx6, mnt12ot2, fex8sd1t, fex8s...
# 9447  [jk62vnz0, zwo7e7gy, twcwhgun, w5s8anjj, z22a5...
#
#                                 origin
# 0                              example
# 1                              example
# 2                              example
# 3                             example2
# 4                             example2
# ...                                ...
# 9443  marcus_borela_1k_gptj6b_20230501
# 9444  marcus_borela_1k_gptj6b_20230501
# 9445  marcus_borela_1k_gptj6b_20230501
# 9446  marcus_borela_1k_gptj6b_20230501
# 9447  marcus_borela_1k_gptj6b_20230501
#
# [9448 rows x 4 columns]

# %%
pd.unique(df.origin)
# Out:
# array(['example', 'example2',
#        'eduseiti_100_queries_expansion_20230501_01', 'leandro_carisio_01',
#        'thales_1k_generated_queries_20230429',
#        'manoel_1k_generated_queries_20230430',
#        'manoel_2k_generated_queries_20230501', 'thiago_laitz_1k_queries',
#        'mirelle_1k_generated_queries_20230501',
#        'hugo_padovani_query_generation',
#        'marcus_borela_1k_gptj6b_20230501'], dtype=object)

# %%
df[df.origin == 'marcus_borela_1k_gptj6b_20230501'][:10]
# Out:
#                                                   query positive_doc_id  \
# 8448  What is the significance of the speculation ab...        jmn8ctlt
# 8449  What is the significance of the TRAP-18 in ass...        ysz3oocp
# 8450  €œIn augustus 2011 wijdde de Journal of the Am...        jnuncmd5
# 8451  What is the estimated reproduction number of C...        k1qq4qgg
# 8452  What is the significance of automatic semantic...        c5zewz3m
# 8453  What is the significance of the lack of second...        7xp143nc
# 8454  What are the enabling opportunities and challe...        l5441kqp
# 8455  【Analysis on epidemic situation and spatiotemp...        35roxf0h
# 8456  What is the significance of environmental sani...        czo533oj
# 8457  What are the challenges posed by the COVID-19 ...        8kfb9alv
#
#                                        negative_doc_ids  \
# 8448  [n26csuks, 09jyekp5, g5bhkd55, x1xzcacy, qv794...
# 8449  [ayt31knx, hycd9zua, xug622im, rjzy3z8t, m54mo...
# 8450  [tfvn7xp8, yxmqmetv, 420px62r, s3xnieig, aey40...
# 8451  [axjrmk48, q4a1n1wm, m2bgbqzg, raav221g, oen0y...
# 8452  [70x44y0t, 5b78ow1j, vr1kmria, 5htvzkpt, borka...
# 8453  [hp8pswt7, xsaat823, huxbyvfd, dyww1yh0, lf2mf...
# 8454  [994i9rtb, xw244riy, y9n9d6s3, fbppvt75, 4og21...
# 8455  [3cj05yc8, qhhssnqk, oqo1xcb3, 8dlnq07a, n30nj...
# 8456  [z59cvvkf, kxwgpymq, b3oh77tu, 95ap34cz, ciuhy...
# 8457  [ozggtbhj, gdhcpmom, vw1lwev0, h76dfo1j, vlzbr...
#
#                                 origin
# 8448  marcus_borela_1k_gptj6b_20230501
# 8449  marcus_borela_1k_gptj6b_20230501
# 8450  marcus_borela_1k_gptj6b_20230501
# 8451  marcus_borela_1k_gptj6b_20230501
# 8452  marcus_borela_1k_gptj6b_20230501
# 8453  marcus_borela_1k_gptj6b_20230501
# 8454  marcus_borela_1k_gptj6b_20230501
# 8455  marcus_borela_1k_gptj6b_20230501
# 8456  marcus_borela_1k_gptj6b_20230501
# 8457  marcus_borela_1k_gptj6b_20230501

# %%
ds['marcus_borela_1k_gptj6b_20230501']['query']
# Out:
# ['What is the significance of the speculation about the catastrophe that awaits once COVID-19 establishes itself in the poorest communities of South Africa?',
#  'What is the significance of the TRAP-18 in assessing the threat of lone-actor terrorism?',
#  '€œIn augustus 2011 wijdde de Journal of the American Medical Association (JAMA) een redactioneel commentaar aan het groeiende probleem van morbide obese kinderen: kinderen die aan een dusdanig ernstige obesitas lijden dat hun gezondheid er direct door wordt',
#  'What is the estimated reproduction number of COVID-19 in Iran?',
#  'What is the significance of automatic semantic description extraction from SBD for emergency management?',
#  'What is the significance of the lack of secondary transmission of Ebola virus from healthcare worker to 238 contacts?',
#  'What are the enabling opportunities and challenges that IoT brings to quadruple helix actors?',
#  '【Analysis on epidemic situation and spatiotemporal changes of COVID-19 in Anhui】.',
#  'What is the significance of environmental sanitation, food safety, and surveillance in reducing the risk for avian influenza virus A (H5N1) transmission in live-bird markets?',
#  'What are the challenges posed by the COVID-19 pandemic on community-dwelling caregivers and persons with dementia?',
#  'What are the special considerations for rhinologic practices during COVID-19?',
#  'What is the significance of the approach to the cardiac workup and monitoring of children with COVID-19?',
#  'What are the key data requirements and challenges in modeling infectious diseases epidemics initiated by global mass gatherings?',
#  'What is the significance of optimal control theory in regulating intracellular signaling pathways of miR-451–AMPK–mTOR–cell cycle dynamics via glucose and drug intravenous administration infusions?',
#  'What is the significance of using machine learning models for the identification of tweets containing traffic incidents from micro-blogs?',
#  'What is the significance of the mental health consequences of COVID-19 in Bahrain?',
#  'What should primary care look like after the COVID-19 pandemic?',
#  'What is the significance of the STS-based learning unit on biological control in enhancing scientific inquiry capability of secondary school students?',
#  'What are the areas requiring further research in fast-track video-assisted thoracoscopic surgery?',
#  'What are the characteristics of the bus transit scheduling problem in BJBUS?',
#  'ernähre ich mich am besten in Zeiten der Corona-Pandemie?',
#  'What is the significance of understanding the characteristics of digital entrepreneurship and digital transformation?',
#  'ipsilateral cervical spinal nerve locoregional anesthesia appears well-tolerated and useful in reducing cumulative anesthetic agent requirement and may decrease the need for additional sedation/analgesia in horses undergoing anesthetized prosthetic laryngoplasty.',
#  'What is the significance of using veno-venous extracorporeal membrane oxygenation as a bridge to lung recovery in a pediatric patient with severe pediatric acute respiratory distress syndrome due to COVID-19?',
#  'What is the significance of a multi-disciplinary approach in reducing surgical site infection in arthroplasty of the lower limb?',
#  'What is the significance of the atypical presentation of MERS-CoV in a Lebanese patient returning from Saudi Arabia?',
#  "What is the significance of the prediction of group learning results from aggregation of an individual's understanding with the Kit-build concept map?",
#  'ervoor te zorgen dat mensen optimaal functioneren, zowel fysiek als mentaal als sociaal.',
#  'What are the safeguards that will be needed to address the threats and vulnerabilities associated with AmI?',
#  'What is the significance of using COVID-19 RNA detection as well as immunoglobulin G antibody testing to guide the timing of resumption of asthma therapy?',
#  'What are the operational considerations and challenges of biochemistry laboratories during the COVID-19 outbreak?',
#  'What is the significance of using a new hidden Markov field for multichannel image segmentation?',
#  'What is the significance of the structured pointcloud segmentation method for extracting individual mangrove trees?',
#  'What is the significance of increasing COVID-19 cases through people who recently returned to Nepal from other countries?',
#  'vernacular print media in Karnataka has done a commendable job.',
#  'What is the significance of the first‐instar larva of Palaestra rufipennis (Westwood, 1841) and other Australian blister beetles (Coleoptera, Meloidae, Nemognathinae)?',
#  'What is the significance of the extent of funding for clinical research projects applying ML techniques by the National Institutes of Health in 2017?',
#  '【The treatment proposal for the patients with breast diseases in the central epidemic area of 2019 coronavirus disease】.',
#  'What is the significance of recent advances and examples of droplet-based microfluidic techniques that have been applied in biochemistry and molecular biology research?',
#  'What is the significance of single incision laparoscopic liver resection for colorectal metastasis through stoma site at time of reversal of diversion ileostomy?',
#  'What is the significance of online reinforcement learning for self-adaptive information systems?',
#  'iliac vein stenting in a patient with a history of radiation and cancer: case report and literature review.. What is the significance of kissing balloons in an artery and adjacent venous segment?',
#  'What are the tips for managing the COVID‐19 pandemic at your institution?',
#  'What is the significance of using fresh-frozen bone allograft in sliding genioplasty?',
#  'What is the significance of the recommendations made in the 2nd ESMO Consensus Conference on Lung Cancer?',
#  'What is the significance of the CRISPR/Cas9 and Cre/Lox system-based express vaccine development strategy against re-emerging Pseudorabies virus?',
#  'What is the significance of transient expression of amiRNAs targeting viral conserved regions at 3′UTR?',
#  'What are the toxicological implications of extended space flights?',
#  'What are the recent advances in pediatric ventilatory assistance?',
#  'What is the significance of biosensor platforms for the detection of SARS-CoV-2?',
#  'What is the significance of pre-procedural surveillance testing for SARS-CoV-2 in an asymptomatic population in the Seattle region?',
#  '《The Korean government recently announced the implementation of mega-projects to solve low employment, population aging, low birth rate and social safety net problems by utilizing AI and ICBM (IoT, Cloud Computing, Big Data, Mobile) technologies.',
#  'What is the significance of the continued use of phototherapy in COVID-19 affected Italy?',
#  'What is the significance of the risk factors for PRRS seropositivity in Danish swine herds?',
#  'What is the significance of the "Expert consensus for the diagnosis, treatment, and prevention of Coronavirus disease 2019 in the elderly"?',
#  'What is the significance of safe endobag morcellation in a single port-access laparoscopy subtotal hysterectomy?',
#  'What is the significance of new dressing materials containing active substances, new treatments for atypical wounds, influencing factors on the healing process and organization in the wound area?',
#  'What is the significance of CT perfusion scanning in patient selection for acute stroke intervention?',
#  'What is the significance of the use of Google Trends for acral symptoms during COVID-19 outbreak in France?',
#  'What is the significance of the emergence of zoonotic pathogens as agents of concern in transfusion medicine?',
#  'What is the significance of surgical prioritization of obstetrics and gynecology procedures in the UK during the COVID-19 pandemic?',
#  'What is the significance of the analytical limits of detection for SARS-CoV-2 detection?',
#  'What are the implications of COVID-19 on Indian agriculture?',
#  'What are the four anastomotic techniques following TaTME?',
#  'What are the challenges of applying data assimilation methods to the coupled dual porosity Stokes model?',
#  'What are the opportunities that are risen for Telecommunications/Information and Communication Technology (ICT) providers at ports?',
#  'What is the significance of preventing COVID-19 deaths through increasing ICU capacity?',
#  'What was the anxiety level among medical students during the SARS epidemic?',
#  'What is the significance of the computed tomography features of COVID-19 infection?',
#  'What is the significance of incorporating external knowledge bases such as DBPedia, WordNet; and exploiting specific features of Twitter for efficient event detection?',
#  'What is the significance of zero-shot learning in improving retrieval performance for non-English languages?',
#  'What is the significance of the IoT-based monitoring system in improving the health of dairy cows?',
#  'What is the significance of the review of the literature published in 2013 on topics relating to the fate of emerging environmental pollutants during wastewater treatment?',
#  'What are the aids to deal with increasing amount of several comorbidities in NORA?',
#  'What is the significance of engaging with our patients and communities in thoughtful dialogue and realistic expectations regarding treatments surrounding COVID-19?',
#  'What is the significance of temporal concurrency and reachability in temporal networks?',
#  'What is the correct by construction approach for the modeling and the verification of CPSs?',
#  'What are the benefits and drawbacks of using each of the 3 technologies to support telehealth?',
#  "What is the significance of the NICE's rejection of pembrolizumab for platinum-refractory urothelial carcinoma?",
#  'What is the significance of preoperative levels of miRNA-208a in predicting postoperative complications in children with congenital heart disease?',
#  'What are the implications of the structural barriers to implementation of lockdown rules in conditions of precarity?',
#  'What is the significance of the combination of specific agile practices with OSS tools?',
#  'What is the significance of the comparison of the efficacy of oseltamivir-peramivir combination therapy versus oseltamivir monotherapy in adults with H7N9 virus infection?',
#  'What are the changes in institutional structures since the 1990s that have had a fundamental impact on GHG?',
#  'What is the significance of the dichotomy inherent in Information Systems where its introduction, for the purposes of creating new or sustaining existing business value, subsequently also inadvertently or deliberately dissipates value?',
#  '€œIn deze tijd waarin de wereld op zijn kop staat door COVID-19 is goede rookstopzorg belangrijker dan ooit.',
#  'What are the major issues and debates pertaining to the normative values and ethical practices of the South African media?',
#  'What is the significance of the set-based approach in dealing with inconsistent measurements in inverse problems?',
#  'What is the significance of timely identification and correction of undernutrition in improving clinical outcomes in COVID-19?',
#  'What is the significance of the level of retrieval success during practice in reversing the testing effect?',
#  'What is the significance of the new pathways for Medicare coverage of innovative PET radiopharmaceuticals?',
#  'What is the significance of using TaqMan Array Card for the detection of respiratory viral pathogens in children under 5 years old hospitalised with acute medical illness in Ballabgarh, Haryana, India?',
#  'What is the significance of the effect of water deficit on biomass production and accumulation of secondary metabolites in roots of Glycyrrhiza uralensis?',
#  'What is the significance of RAS imbalance in the development of 2019-nCoV-related multi-organ injury?',
#  'What is the significance of timely detection of localized excess influenza activity in Northern California?',
#  'What is the significance of building a polyglot data access layer for a low-code application development platform?',
#  'What is the significance of the nested pattern of Sonoran Desert woody vegetation in remnant islands within metropolitan Phoenix?',
#  'What is the significance of the consensus recommendations for India and Bangladesh for the use of pneumococcal vaccine in mass gatherings with special reference to Hajj pilgrims?',
#  'What is the significance of repeat angiography in the diagnosis of iatrogenic anterior cerebral artery territory pseudoaneurysm following endoscopic sinus surgery?',
#  'What is the significance of the genetic variability of the S1 subunit of enteric and respiratory bovine coronavirus isolates?',
#  'What is the significance of the revised regulation of infectious waste management?',
#  'What is the significance of holistic patient flow simulation following system approach?',
#  'What is the significance of adopting a single incision laparoscopic technique in performing a Nissen fundoplication?',
#  'What is the significance of using subsampling in order to get a test dataset with class imbalance equal to the one observed in the wild?',
#  'What are the challenges faced by the urban management and planning systems in Slavutych atomograd following the Chornobyl Nuclear Power Station explosion?',
#  'What is the significance of using captions of clicked images as the target for the reformulation mechanism?',
#  'What are the three ways in which computational biology has contributed to the understanding of host-pathogen interaction?',
#  'iav inhibition by flexible sialylated nanogels 400 times as compared to a rigid sialylated nanogel in the hemagglutination inhibition assay.',
#  'What is the significance of nursing leadership in disaster preparedness and response?',
#  'What is the significance of discontinuing systemic treatment for psoriasis during the COVID-19 pandemic?',
#  'What is the significance of biocompatible, biodegradable, non-toxic (organic, inorganic and hybrid) nanocarriers that encapsulate and shield the siRNA from the different harsh environment and provides the increased systemic siRNA delivery?',
#  'What is the significance of combining SLiVER with CADP to analyze multi-agent systems?',
#  'What is the significance of nasopharyngeal and stool swab for detecting infected children?',
#  'What are the most famous nanotechnological drug delivery systems that are already used in clinical practice and clinical evaluation or in academic research?',
#  'What is the significance of the discovery of membranotropic peptides in viral entry?',
#  'What are the responses of tropical bats to habitat fragmentation and disturbance?',
#  'What are the demographic and clinical determinants for autopsy in unexplained deaths possibly resulting from infectious causes?',
#  'What is the significance of recent advances in multicistronic expression technology in view of multigene metabolic engineering?',
#  'What is the significance of the objective measures for sentinel surveillance in network epidemiology?',
#  'What is the significance of service robots in disinfection in medical institutions?',
#  'What is the significance of the Glasgow Subgraph Solver in solving subgraph isomorphism problems?',
#  'What is the significance of inadequate peritoneal closure, trocar site herniation, or adhesions in the development of small bowel obstruction?',
#  'What is the significance of individualized PEEP titration guided by intratidal compliance profile analysis on regional ventilation assessed by electrical impedance tomography?',
#  'What is the significance of nosocomial transmission of Crimean–Congo haemorrhagic fever in healthcare settings?',
#  'What is the significance of the first 16 cases involving pregnant women, admitted to an urban-suburban community general hospital in Wayne County Michigan, from 26 March to 10 April 2020?',
#  'What is the significance of the proline-altered peptide ligand in improving the recognition of the naturally occurring MHC-I-restricted LCMV-associated immune escape variant Y4F by CD8(+) T cells?',
#  'What is the significance of anaerobic codigestion of food waste with waste-activated sludge in terms of sustainability?',
#  'What are the unique optical properties of GNPs that make them suitable for biosensor development?',
#  'What is the significance of the clinical presentations and paraclinical findings of the first confirmed cases and mortalities in the initiation of the outbreak of COVID-19 in Iran?',
#  'What is the significance of the use of an antiviral filter attached to a pleural drain bottle to prevent aerosol contamination with SARS-CoV-2?',
#  'What is the significance of botulinum toxin in the treatment of spasmodic torticollis?',
#  'What is the significance of targeting pericytes for neurovascular regeneration?',
#  '【What are the causes of repeated outbreaks of hepatitis A among adults in Korea?】',
#  'What is the significance of co-detection of RP in patients with Covid-19 pneumonia?',
#  'What is the significance of comparing outbreak detection algorithms?',
#  'What are the benefits of the single-incision laparoscopic technique?',
#  'What is the significance of engineering control of airborne disease transmission in healthcare facilities?',
#  'What are the challenges faced by nurses in the COVID-19 pandemic?',
#  'What is the significance of leveraging the available antonyms of the original query terms for producing dual queries?',
#  'What is the significance of the strategy of picornavirus evading host antiviral responses?',
#  'What is the significance of distant supervision for extractive question summarization?',
#  'What is the significance of the enterotoxic effect of stool supernatant of Cryptosporidium-infected calves on human jejunum?',
#  'What is the significance of the proposed LFB assay for detection of nodavirus virions in fish samples?',
#  'What is the significance of transthoracic echocardiography in the diagnostic and therapeutic management of myocardial damage in COVID-19 patients?',
#  'What is the significance of assessing the preparedness and response of healthcare professionals to Zika outbreak?',
#  'What is the significance of restricting long-range travels in limiting rabies persistence in a large and fragmented dog population?',
#  'What is the significance of the heuristic approach in predicting RNA pseudoknots?',
#  'What is the significance of identifying, evaluating, and treating patients with pneumonia-associated rhabdomyolysis and acute renal failure?',
#  'What is the significance of the FilmArray Meningitis/Encephalitis Panel in the diagnosis of HHV-6 encephalitis?',
#  'What is the significance of novel and diverse recommendations in improving user satisfaction?',
#  'What are the additional properties of the family of fuzzy implication functions which are invariant with respect to powers of a strict t-norm?',
#  'What is the significance of considering the "new normal" in the post-COVID era?',
#  'What is the significance of the Kaizen–Kata methodology in solving operational problems in health care?',
#  'What is the significance of the new hybrid quantum annealing algorithms for solving VRP and CVRP?',
#  'What is the significance of domestic politics in explaining the use of trade and travel barriers during disease outbreaks?',
#  'What is the significance of the design of a smart inhaler with electrostatic sterilizer and the utilization of cationic amphiphilic peptides for COVID-19 patients?',
#  'What are the insights into IFITM3 trafficking and activity that were provided by studies of IFITM3 post-translational modifications?',
#  'What is the significance of prevention of viral infections in solid organ transplant recipients?',
#  'What are the consequences of clinical empathy in patients and nurses?',
#  'What are the dangers of a heightened public profile in magnifying the inequality of diseases and undermining three key ethical concepts?',
#  'What are the potential and long-term implications of the knowledge gained from human microbiome research for the developing world?',
#  'What is the significance of the multidisciplinary approach to the minimally invasive pulmonary vein isolation for treatment of atrial fibrillation?',
#  'What is the significance of the label-free microcantilever-based immunosensors for highly sensitive determination of avian influenza virus?',
#  'What is the significance of extending the notion of conserved haplotype blocks to pangenomes?',
#  'What are the novel herbal technologies developed by DRDO?',
#  'What is the significance of the classification, description, hosts, key developments, diagnostic techniques, and diagnostic reagents for the transmissible turkey enteritis virus?',
#  'What is the significance of single-use instrumentation in reducing the risk of SSIs in TKA?',
#  'What is the significance of plastic surgery closure of complex scalp incisions in reducing the incidence of wound complications in patients who underwent previous neurosurgical intervention, XRT administration, and preoperative bevacizumab administration?',
#  '《A Characterization for Procedural Choice Based on Dichotomous Preferences Over Criteria》 is a formal model of procedural choice based on preferences over criteria.',
#  'What is the significance of the integrity of respirator fit and seal in maintaining the effectiveness of N95 respirators?',
#  'What are the ideal properties of 3D scaffolds for enhanced bone regeneration in osteonecrosis?',
#  'What is the significance of the theoretical understanding of the role of participation in health promotion and how can it be fostered?',
#  'What is the significance of the up-regulation of novel gene mfgl2 in lungs in the development of SARS associated lung damage?',
#  'What is the significance of the role of nursing informatics in the school nurse?',
#  'What is the significance of the isolation of cancer-derived small EVs (30–120 nm) with high recovery and reproducibility at an optimum sample flow rate?',
#  'What are the advantages of endovascular treatment of carotid-cavernous fistulas?',
#  'What are the possible pharmacological interventions in patients to decrease negative effects of CPB and to improve post-operative outcome with regard to heart and other organs like brain, kidney, or lung?',
#  'What is the significance of hybridization of rough sets and fuzzy sets techniques in linguistic data summarization?',
#  'What is the significance of the SMaRT/Mlx‐γ/DHX36 circuitry in the control of myogenesis?',
#  'What is the significance of the interpretation and relevance of the results produced by advanced molecular techniques?',
#  'What is the significance of marsupialization as a treatment option for nictitating membrane cyst secondary to surgical correction of gland prolapse using conjunctival pocket technique in dogs?',
#  'What is the significance of the new perspective offered by fuzzy set approach to the measurement of polarization?',
#  'What is the significance of choreography automata for the choreographic modelling of communicating systems?',
#  '【Nursing strategy for device related pressure injuries】',
#  'What is the significance of intraoperative GDT in improving GI recovery in low to moderate risk patients?',
#  'What is the significance of the serological resemblance between human and bovine Breda-like viruses?',
#  'What is the role of scientific collections in scientific preparedness?',
#  'What is the significance of the incremental meta-docking approach for structural prediction of pMHC complexes?',
#  'What is the significance of finding the optimal cluster centers for image clustering?',
#  'What is the significance of verifying SGAC access control policies?',
#  'What lessons can be learned from the US Biodefense program to inform international efforts to build a medical countermeasure enterprise for emerging infectious diseases?',
#  'What is the significance of the hidden assumptions of mastery learning heuristics?',
#  'What is the significance of the newly introduced da Vinci Single-Site® platform in urogynecology?',
#  'What is the significance of the prediction of RNA-protein interactions using conjoint triad feature and chaos game representation?',
#  'What is the significance of the MHC-CRE/ICS enhancer region in controlling MHC class I gene expression in astrocytes?',
#  'What is the significance of the low‐cost ventilator for patients with COVID‐19?',
#  'What is the significance of intercontinental spillover of a new influenza virus in cattle?',
#  'What is the significance of preoperative gastric ischemic conditioning prior to esophagogastrectomy?',
#  'What is the significance of the CD95/CD95L signaling pathway in carcinogenesis?',
#  'What is the significance of the recovery of pituitary function following treatment of an unruptured giant cavernous carotid aneurysm using Surpass flow-diverting stents?',
#  'What is the significance of the occurrence of multi-drug resistant bacteria in healthy dogs in Sweden?',
#  'What is the significance of routine blood culture testing in predicting mortality in invasive pneumococcal pneumonia?',
#  'What is the significance of tabletop exercise in preparing institutions of higher education for an outbreak of COVID-19?',
#  'What are the challenges faced by the oral and dental care providers in providing oral and dental care during the COVID-19 pandemic?',
#  'What is the significance of antimicrobial-associated harm in critical care?',
#  'What are the opportunities and challenges in developing next-generation influenza vaccines?',
#  'What is the significance of self‐assembling peptide cages (SAGEs) as a delivery platform for immunogenic components?',
#  'What is the significance of the Gaussian Pyramid method in the restoration of range images?',
#  'What are the main constraints to the current global vaccine innovation system for achieving Sustainable Development Goals?',
#  'What is the significance of the proposed approach for solving 2D elastic boundary value problems defined in domains with inclusions with different material properties?',
#  'What is the significance of the at-home general chemistry laboratories during the COVID-19 pandemic?',
#  'What is the significance of the first fully integrated and automatic distributed cube-and-conquer solver Paracooba targeting cluster and cloud computing?',
#  'What are the non-formal educational programmes in the Philippines and Taiwan?',
#  'What is the significance of the recombination breakpoint at position 22774, encoding the Group 2a CoV-specific hemagglutinin esterase gene, exhibiting high bootstrap support for clustering with RbCoV HKU14, which was previously detected in domestic rabbits in China?',
#  'What is the significance of the custom-made 3D-printed ergonomic laryngoscope support grip in improving the performance of novice intubation in a simulated easy and difficult airway scenario?',
#  'What is the significance of the ALERT algorithm in determining the onset of increased respiratory virus incidence?',
#  'What is the significance of nearly complete genome sequence of an echovirus 30 strain from a cluster of aseptic meningitis cases in California?',
#  'What is the significance of cytotoxicity testing in drug discovery?',
#  'What are the characteristics of neonatal transports in California?',
#  'What are the benefits of minimally invasive procedures?',
#  'What is the significance of direct cloning and production of fully human HCAbs from sorted population of transgenic mouse plasma cells carrying a human HCAb locus?',
#  'What is the significance of the comparison of the algorithms in the context of a dial a ride problem?',
#  'What is the significance of the effects of these technologies on the properties of edible packaging?',
#  'What is the significance of establishing a diagnosis of a rare vascular tumor?',
#  'What is the significance of the proposed e-government implementation framework for developing countries?',
#  'What are the challenges in expanding existing ASPs in pediatric acute care facilities?',
#  'What is the significance of alteration of intracerebral cytokine production in mice infected with HSV-2?',
#  'What are the three predictive metrics of how students interact with MOOC videos?',
#  'What is the significance of the interactive visualization tool in the analysis of MERS data?',
#  'What is the significance of better preparation and support for foster parents dealing with moves and removals of foster children?',
#  'What is the significance of the correlation between the pre-existing antibody titres against MHV3 and the mean survival time of susceptible animals?',
#  'What is the significance of non-cross-linked intact porcine-derived acellular dermal matrix in laparoscopic inguinal herniorrhaphy?',
#  'What is the significance of the risk of contracting COVID-19 in patients with T1D?',
#  'What is the significance of the in planta activity of anti‐rep ribozyme in presence of a RNA silencing suppressor?',
#  'What are the indications for the safe post-mortem management of HID patients?',
#  'What is the significance of the progress made in the past few years in the specific settings of fine-grained complexity and lower-bounds, [Formula: see text] multiplicative approximations, k-bounded relaxations, streaming algorithms, purely combinatorial algorithms, and other recently proposed variants?',
#  'What is the significance of nonsurgical evacuation of retained hemothorax during ECLS?',
#  'What are the properties of the IR axioms that are desirable for the contact recommendation task?',
#  'What is the significance of the proposed modeling method for SAR of microservice architectures?',
#  'What is the significance of transcervical laryngeal ultrasound in the evaluation of patients suspected of having functional laryngeal abnormalities?',
#  'What is the significance of personal concern about COVID-19 in Spain?',
#  "What is the significance of the UK's exit from the EU on scientists' assessment of their international mobility and future job market prospects?",
#  'What is the significance of delayed specific IgM antibody response in COVID-19 patients with severe progression?',
#  'What is the significance of the updated guidance for national pandemic planning efforts?',
#  'What is the significance of rapid and specific microbiologic examination in improving the diagnostic performance for atypical pneumonia?',
#  'What is the significance of identifying the existing knowledge gaps in the leishmaniasis studies in Sri Lanka?',
#  'What is the significance of adequately powered randomized controlled trials in evaluating fatigue management interventions in people with progressive MS experiencing high levels of fatigue?',
#  'What is the significance of the Bayesian approach for detecting host influences on pathogen evolution?',
#  'What is the significance of the single-incision laparoscopy with flexible-tip laparoscope in the treatment of pancreatic pseudocyst?',
#  'What is the significance of prophylactic and therapeutic effects of egg yolk immunoglobulin against TGEV in piglets?',
#  'What is the significance of genetic structure of mountain lion (Puma concolor) populations in California?',
#  'What is the significance of the evolution of cAMP signaling in the Dictyostelid social amoebas?',
#  'What is the significance of transitivity in altering the SIS dynamics on a coevolving network?',
#  'What is the significance of identifying novel pathogens or plausible contaminants that may associate to a particular kit or method?',
#  'What is the significance of biosensors based on imaging ellipsometry techniques?',
#  'What is the significance of the involvement of the CNS in COVID-19?',
#  'What is the significance of next-generation sequencing in public health?',
#  'What are the main features of the recent emerging pathogens with a particular focus on the recent and ongoing Ebola outbreak?',
#  'What is the significance of the CEAI in measuring the access to CPE among the health workers?',
#  'What is the significance of the app in helping farmers to make better informed planting and harvesting decisions?',
#  "What is the significance of the German virologist's race for swine flu test?",
#  'What is the significance of the method developed to profile and search for RNA pseudoknot structures in genomes?',
#  'What are the indications for reversal of gastric bypass and jejunoileal bypass?',
#  'What is the significance of the use of unfractionated heparin in COVID-19?',
#  'What is the significance of regional trading blocs in tourism?',
#  'What is the significance of the apparent discontinuous transcription of variant surface antigen genes?',
#  'What is the significance of the size structure of brook trout and brown trout in relation to the features of their habitats?',
#  'What is the significance of selection of patients in whom sufficient fibroid volumes can be treated safely using the MRgFUS system?',
#  'What is the significance of the model in analysing the dynamic and adaptive relationships between cannabis usage, anxiety and sleep?',
#  'What is the significance of the newly developed SCAR marker for Chinese Race 34MKG of Puccinia graminis f.',
#  'What are the unique features of the obstetric population that warrant additional consideration in order to optimize the care received by expectant mothers and their fetuses or newborns in the face of future natural or biologic disasters?',
#  'What is the significance of using neural networks as a surrogate simulation model?',
#  'What are the non-technical aspects of airway management that are critically important for communication and decision making during airway crises?',
#  'What is the significance of being transported to a cardiac resuscitation center in improving the survival of adult patients suffering from an out-of-hospital cardiac arrest?',
#  'What is the significance of the study of social networks in understanding the emerging coordination and knowledge transfer process during a disease outbreak?',
#  'What is the significance of the associations between species assemblages and environmental factors in the savannas?',
#  'What are the symptoms reported by passengers and crewmembers on commercial aircraft?',
#  'What is the significance of integrated surveillance across geographic frontiers and modelling across scientific specialties?',
#  'What is the significance of a high index of suspicion for superimposed fungal infections in patients who are critically ill and immunocompromised?',
#  'What is the significance of laparoscopic treatment of left renal artery entrapment?',
#  'What is the significance of the extended imaging lifetime of the functionalized silica nanoparticles?',
#  'What is the significance of the presence of HBoV in respiratory secretions, serum and stool?',
#  'What are the most effective measures to control viral contamination of food and environment?',
#  'What is the significance of essential noninvasive multimodality neuromonitoring in the critically ill patient?',
#  'What is the significance of the intermittent migration of T cells in the lung?',
#  'What is the significance of critical care in the management of rheumatologic emergencies?',
#  'What is the significance of the identification of new viral agents that had previously escaped detection by routine cell culture procedures?',
#  'What are the implications of COVID-19 in the management of patients with gastrointestinal diseases?',
#  'What is the significance of destabilizing science in the 2008 WHO/Joint UN Program on HIV/AIDS controversy?',
#  'What are the currently available tools to undertake controlled crystal dehydration?',
#  "What is the significance of the uniform distribution in estimating the largest possible value of Shannon's entropy?",
#  'What is the significance of applying tidal volumes of less than 6 mL/kg in improving lung protection in patients with ARDS?',
#  'What are the benefits of a visiting clinical professor program for critical care pharmacy?',
#  'What is the significance of the pathophysiological mechanisms of lung structural remodelling in LHD?',
#  'What is the significance of the folding mechanism of the pseudoknot in the high-efficiency frameshifting RNA pseudoknot?',
#  'What is the significance of the proposed method for the identification of manoeuvre events in real-world conditions?',
#  'What is the significance of combining machine learning with game-theoretical concepts in medical diagnosis?',
#  'What are the advantages of r-PRP over transabdominal robotic radical prostatectomy?',
#  'What is the significance of the antibody changes to cytomegalovirus and herpesvirus in the children with acute hepatitis A?',
#  'What are the challenges in the diagnosis and treatment of marine mammal zoonotic diseases?',
#  'What is the significance of a significant inverse correlation between SARS-CoV-2 disease burden and incidence of Malaria?',
#  'What is the significance of detection and quantification of fecal indicators and waterborne pathogens?',
#  'What is the significance of increased HIV-1-specific T cell responses in individuals who are infected with HIV-1 with suppressed blood viremia, while receiving bNAb therapy during ART interruption?',
#  'What is the significance of the role of the neutral amino acid transporter B(0)AT1 (SLC6A19) in Hartnup disorder and protein nutrition?',
#  'What is the significance of the single-port device in intragastric surgery?',
#  'What are the common surgical procedures performed in small mammals?',
#  'What are the advantages of liposome-based gene therapy?',
#  'What is the significance of pathogen detection in the genomic era?',
#  'What is the significance of the Event-B method in the verification of critical systems properties?',
#  'What is the significance of granulocyte apoptosis to resolution of inflammation at the respiratory mucosa?',
#  'What is the significance of the new tasks in ImageCLEF 2020?',
#  '€œInfecties van de bovenste luchtwegen in het algemeen en infecties van de bovenste luchtwegen in het bijzonder".',
#  'What is the significance of the program for predicting frameshift sites of general type?',
#  'What is the significance of the time complexity of the direct solver for hierarchically adapted meshes?',
#  'What is the significance of closed-loop controllers in anesthesia?',
#  'What is the significance of simultaneous thoraco-laparoscopic hernia repair?',
#  'What is the significance of extracting rare itemsets?',
#  'What is the significance of targeting SARS-CoV-2 viral receptors as a means for reducing infectivity and improving antiviral and immune response?',
#  'What are the similarities between mass death incidents predominantly within the Canadian historical record, including disasters and pandemics?',
#  'What is the significance of early recognition and initiation of supportive management in improving the outcome of ALF in children?',
#  'What is the significance of using venography to assess for venous stenosis or vascular anomalies in individuals with multiple catheterizations or in close proximity to cancer?',
#  'What is the significance of biopolymeric nanomaterials for photocatalytic degradation of dyes?',
#  'What is the significance of the diagnosis-related groups (DRG) statistics in providing information on the healthcare needs of long-term invasively ventilated patients?',
#  'What is the significance of the past experiences of being stigmatized in the SARS outbreak in influencing the knowledge perceptions of and the adoption of the preventive health behaviors against H1N1?',
#  'What is the significance of the first robotic laparoendoscopic single-site radical prostatectomy (R-LESS-RP) with the single-site VesPa platform?',
#  'What is the current status of clinical islet transplantation using DCD donors in Japan?',
#  'What is the significance of the temporal changes in expression of FoxA1 and Wnt7A in isolated adult human alveolar epithelial cells?',
#  'What is the significance of cross-modal graph convolutions for cross-modal retrieval?',
#  'What is the significance of the creation and size of the gastrojejunostomy in the surgical treatment of morbid obesity?',
#  'What are the unique challenges of promoting vaccine acceptance during the COVID-19 pandemic?',
#  'What are the recommended strategies for revascularization in patients with Type 2 DM?',
#  "What is the significance of stochastic volatility in the context of early warning indicator for banks' credit risk?",
#  'What is the significance of antimicrobial drug resistance in Shiga toxin-producing E.',
#  'What is the significance of obtaining informed consent in the context of off-label use?',
#  'What is the significance of the variable-gain control strategy in balancing the conflicting objectives of fast pressure buildup and a stable flow response?',
#  'What is the significance of the presence of Leishmania DNA in the blood samples of bats?',
#  '【Analysis of adenovirus infection in acute respiratory tract infection cases in Shanghai from 2015 to 2019】.',
#  'What is the significance of recent advances in the development of DNA vaccines to some pathogenic protozoa and helminths?',
#  'What is the significance of the molecular docking, molecular dynamics (MD) simulations, and binding free energy calculations against the SARS-CoV-2 Mpro?',
#  'What is the significance of the solidarity statement issued by the South Asian Family Physicians?',
#  'What is the significance of the proposed method in detecting interactions among variables?',
#  'What are the principles of health surveillance in conflict and disaster situations?',
#  '€œMicro-organismen zijn essentieel voor alle levensprocessen, ze zijn dan ook alom vertegenwoordigd op aarde.',
#  'What are the current state of knowledge in the municipal solid wastes and wastewater treatment and utilization technologies and recommend practical solution options and future research and development needs?',
#  'What is the significance of the coupling between innovation and financing at inception of a business?',
#  'What is the significance of nutritional therapy in the treatment of COVID-19?',
#  'What is the significance of the host response to acute VZV infection in the lung?',
#  'What is the significance of the execution order of interactions in parametric component-based systems?',
#  'What are the advantages of using plant-based vaccines over current vaccine technologies?',
#  'What is the significance of CDV in the Iberian lynx population?',
#  'What is the significance of long-term surveillance in seabird populations of polar ecosystems to detect the potential introduction of exotic strains and potential existence of a local epidemiological cycle for avian influenza viruses?',
#  'What is the significance of the substrate-induced mechanism for modulating PRMT1 product specificity?',
#  'What is the significance of the use of rituximab in patients with SLE?',
#  'What are the immunological disturbances associated with malarial infection?',
#  'What is the significance of non-unique probes in identifying viruses?',
#  'What is the significance of the use of immunomic microarrays as a tool for advances in systems biology of cellular immune responses?',
#  'What is the significance of unusually rapid development of pulmonary hypertension and right ventricular failure after COVID-19 pneumonia?',
#  'What is the significance of controlled, low temperature irradiation of allograft tendons for ACL reconstruction?',
#  'What is the significance of PPAR-gamma expression in peritoneal endometriotic lesions in relation to pain experienced by patients?',
#  'What is the significance of increasing communication and cooperation across ministries and sectors to improve zoonotic pathogen surveillance in wildlife?',
#  'What is the significance of the use of the Aura-i laryngeal mask and the aScope-2 devices in the management of an unpredicted difficult airway?',
#  'What is the significance of addressing ARDS using stem cell therapies in clinical trials?',
#  'What is the significance of the suppression of Nrf2-regulated enzyme activity and Nrf2 expression in human lung cancer A549 cells by Cinnamomi Cortex extract?',
#  'What is the significance of the proposed algorithm in the context of highly imbalanced datasets?',
#  'What is the significance of posting research studies addressing infectious disease outbreaks as preprints?',
#  'What is the significance of studying the impact of network evolution on spread of diseases?',
#  'What is the significance of the introduction of the structured L-fuzzy relational erosion and dilation operators?',
#  'What is the significance of using facemasks in reducing the spread of pandemic (H1N1) 2009?',
#  'What is the significance of noninvasive ventilation in the treatment of pediatric acute respiratory failure?',
#  'What is the significance of revisiting the history and evolving definition of scientific literacy?',
#  'What is the significance of numerical simulation of heat transfer in an enclosure with time-periodic heat generation?',
#  'What is the significance of detection and occurrence of FIB and pathogens?',
#  'What are the key policies, acts and programmes undertaken by the government of India to promote good health and wellbeing?',
#  'What is the significance of the recovery policy in the cross-docking location problem?',
#  'What is the significance of the use of combined hormonal contraceptive in protecting women from the most serious complications of COVID-19?',
#  'What is the significance of the COVID-19 Gene and Drug Set Library?',
#  'What are the indications for the use of prosthetic reconstruction of the chest wall?',
#  "'Het went nooit helemaal'.",
#  'What is the significance of the use of laparoscopy in the treatment of pediatric and adolescent gynecologic pathology?',
#  'What is the significance of broadly cross-reactive antibodies in the human B cell response against pandemic H1N1 influenza infection?',
#  'What is the significance of the sequence variations of the "2009 H1N1" (swine or Mexican flu) influenza A virus strain neuraminidase for drug treatment and vaccination?',
#  'What is the significance of the pulled-through technique in repairing the disconnected stent-graft limb?',
#  'What is the significance of the use of immunofluorescence and immunoperoxidase techniques in the demonstration of canine parvovirus antigens in sections of canine tissue?',
#  'What are the challenges in controlling the spread of highly infectious pathogens such as SARS-CoV-2 in correctional and detention facilities?',
#  'What is the significance of the association between RANTES-28 and SDF-1 gene polymorphisms and occurrence of SLE in Malaysia?',
#  'What is the significance of studying signaling pathways in SARS-CoV patients?',
#  'What is the significance of tracking temporal relationships in the recovery of olfactory function in COVID-19 patients?',
#  'What is the significance of epidemic diffusion in causing many deaths and more people of permanent sequela?',
#  'What is the significance of the review of the ethnomedicinal uses, phytochemistry, and pharmacology of the genus Calophyllum?',
#  'What is the significance of coil embolization in the treatment of a traumatic arteriovenous fistula of the lower extremity?',
#  'What is the significance of neighborhood saturation in malware propagation in WSN?',
#  'What is the significance of the proposed disinfection system for passenger luggage at airports and train/bus stations?',
#  'What is the significance of early identification and appropriate medical care for males with lab-confirmed COVID-19?',
#  'What is the significance of incorporating knowledge distribution, semantic features, and difficulty features in enhancing the ability of knowledge tracing?',
#  'What are the four ways the implementation challenge of the global biodiversity framework can be addressed?',
#  "What are the special security issues arising when an organization attempts to create an Enterprise Single Sign-On (ESSO) solution that includes both legacy applications hosted within traditional organizational firewalls and a new breed of 'Cloud Based' solutions that are following the Software as Service (SaaS) model and therefore can be hosted with any number of Service Providers (SP) 'in the cloud�",
#  'What is the significance of contextualized predictions in improving the interpretability of the predictions?',
# ...
#  'What is the significance of SemTab 2019?',
#  'What is the significance of ADAM-17 in disease?',
#  'What is the significance of co-expression of LAG3 and CD49b in IL-10-producing T cell lineages?',
#  'What are the key considerations around maternal immunization introduction and delivery?',
#  'What is the significance of the mobility elasticity of crime in the pandemic?',
#  'What is the significance of the knowledge obtained from the vaccine development efforts for MERS and SARS?',
#  'What is the significance of blocking the activity or production of type I IFN in HIV infection?',
#  'What is the significance of the findings from both invertebrate and vertebrate model systems suggesting that all of these proteins increase secretory capacity in response to increased protein load?',
#  'What is the significance of detecting mutations in the MinION sequencing data?',
#  'What is the significance of the method proposed by Levin for calculating Fourier integrals?',
#  'What is the significance of the role of viral mRNA sequences and secondary structures in the regulation of ribosomal frameshifting?',
#  'What is the significance of the impact of weight management interventions on mental health in adults with overweight and obesity?',
#  'What was the pattern of mortality in the Southern Cone outbreak?',
#  'What is the significance of the full-length genome sequence of the French PEDV isolate?',
#  'What is the significance of the differential diagnosis of diffuse alveolar hemorrhage in the context of vasculitis?',
#  'What is the significance of using a dermic regeneration template (Integra™) in rhinoplasty?',
#  'What is the significance of surges in ventilator use during influenza outbreaks?',
#  'What is the significance of the finding of rotavirus in the stool samples of the affected infants?',
#  'What is the significance of genomics in the study of Ebola virus disease?',
#  'What is the significance of the colorimetric assay for the detection of Leishmania major and Trypanosoma cruzi?',
#  'What is the significance of the absence of recovery from AKI?',
#  'What is the significance of monitoring HHV-6 reactivation in stem cell transplant recipients?',
#  'What is the significance of the first H1N1-associated death in Germany?',
#  'What is the significance of the ACG slide in the preparation of glycan microarrays?',
#  'What are the theoretical advantages and disadvantages of NAVA compared with other modes?',
#  'What is the significance of the production of mAb by DNA immunization?',
#  'What is the significance of CEACAM1 in CD8(+) T cell function?',
#  'What is the significance of the protocol used to examine hydrogen exchange in a membrane protein?',
#  'What is the significance of staged endovascular and surgical therapy in treating a retained intracranial foreign body?',
#  'What is the significance of routine postoperative UGI contrast study after SG?',
#  'What is the significance of the cytoskeletal architecture of the airway smooth muscle cell in the regulation of airway responsiveness?',
#  'What is the significance of the association of CD44/CD24 expression with gastric cancer recurrence?',
#  'What is the significance of the immune mechanism and expression systems for transgenic plant vaccines?',
#  'What is the significance of translational research in respiratory medicine?',
#  'What is the significance of comparative modeling in drug discovery?',
#  'What is the significance of the newly recognized and therapeutically attractive neutrophil characteristics in the context of liver transplantation?',
#  'What is the significance of increased tendency to form alternate, incompletely folded structures in increasing frameshifting efficiency?',
#  'What is the significance of this new network in achieving Super-Resolution on medical images?',
#  'What is the significance of UQ workflow over the existing fusion codes?',
#  'What is the significance of the role of HA in the entry pathway of influenza virus?',
#  '【Clinical characteristics of 30 medical workers infected with new coronavirus pneumonia】.',
#  'What is the significance of the proposed methods in the context of the skewed class distribution?',
#  'What is the significance of attenuation of progression of renal injury and cardiac remodeling by RDN in SHRs-ob?',
#  'What is the significance of the new knowledge about healthcare-associated atypical pneumonia?',
#  'What is the significance of image guidance in liver surgery?',
#  'What is the significance of the framework for analyzing social-ecological models of emerging infectious diseases?',
#  'What is the significance of the immune response in sentinel nodes draining human urinary bladder cancer?',
#  'What is the significance of verification of nested models?',
#  'What is the significance of early recognition and targeted treatment in improving clinical outcomes in hemophagocytic lymphohistiocytosis?',
#  'What is the significance of performing OHT in the early phase of the COVID-19 pandemic?',
#  'What is the significance of the management of hyponatraemia in COVID-19 patients?',
#  'What is the significance of the observed differences in the distribution of DC-SIGN promoter variants in the three ethnic groups?',
#  'What is the significance of the therapeutic efficacy of lentiviral vectors in the treatment of glioblastoma?',
#  'What are the implications of disrupted care or the introduction of the virus by their caregivers?',
#  'What is the significance of surgical resection of mediastinal lymph nodes in the treatment of pulsatile tinnitus?',
#  'What is the significance of videoscopic-assisted transposition of the basilic vein for creation of transposed brachiobasilic arteriovenous fistulae?',
#  'What is the significance of the proposed method in emergency decision making?',
#  'What is the significance of the HLA supertype, genome‐wide scan for SARS‐specific cytotoxic T cell epitopes?',
#  'What is the significance of the balance between sumoylation and desumoylation?',
#  'What are the key emerging life science technologies of concern?',
#  'What is the significance of using BsMAb for the detection of various infectious diseases?',
#  'What is the significance of the preoperative and postoperative management of patients undergoing LS?',
#  'What is the significance of the passage of time during the lockdown?',
#  'What is the significance of using Microsoft Excel to streamline the process of creating a single-line search string?',
#  'What is the significance of the decrease in cerebral rSO2 during CD under spinal anesthesia?',
#  'What is the significance of the detection of novel paramyxoviruses in free-ranging European bats?',
#  'What is the significance of in vitro flow diversion effects of the devices?',
#  'What is the significance of the protective role of antigenic sites on the envelope protein of Hantaan virus defined by monoclonal antibodies?',
#  'What is the significance of visualizing the cohesion of the document(s)?',
#  'What is the significance of the mathematical basis for the convergence of FGCMs?',
#  'What is the significance of prevention in the prevention of tick-borne illnesses?',
#  'What is the significance of identifying PPARα/γ/δ pan agonists?',
#  'What are the key mechanisms that regulate the transcription of pro-inflammatory chemokines in ovarian cancer cells?',
#  'What is the significance of the paper from Lombardy, the epicentre of the pandemic in Italy?',
#  'What are the risk factors for infectious complications after pediatric lung transplantation?',
#  'What is the significance of the BRI in the context of health security?',
#  'What is the significance of NATs in the diagnosis of respiratory virus infections?',
#  'What is the significance of replication and transmission of bovine FLUDV in guinea pigs?',
#  'What is the significance of blocking the protein DPP-4 in treating coronavirus infection?',
#  'What is the significance of the PA‐SIA method in detecting virus particles?',
#  'What is the significance of the consistency of viral shedding patterns between self-collected nose and throat swabs and the earlier and later measurements?',
#  'What is the significance of the emergence of Internet activity addressing the experiences of young people in two British communities: South Asian and Chinese?',
#  'What is the significance of the use of RATG in conditioning for childhood allogeneic stem cell transplantation?',
#  'What is the significance of the ACE2/Ang-(1–9) axis in the protection of the heart and vessels from adverse cardiovascular remodeling?',
#  'What is the significance of routine radiography in the follow-up of extremity fractures?',
#  'What are the economic foundations of dynamic pricing?',
#  'What is the significance of the revisionist view of the relationship between Israeli and American Jewries?',
#  'What is the significance of NHC catalysis in guiding the application to a versatile druggable isatin library?',
#  'What is the significance of the macaque model in studying tuberculosis?',
#  'What is the significance of offsetting the increase in susceptibility to infection associated with stressful exercise?',
#  '《What is the significance of the generalized phi-transformation of aggregation functions?》',
#  'What is the significance of the identified cross-reactive antibodies targeting a conserved epitope on influenza A hemagglutinin?',
#  'What are the drivers of disease emergence in bat populations?',
#  'What is the significance of the nonproteinogenic residues identified in the screening?',
#  'What is the significance of the method of nearest neighbors for dealing with a specific type of relative information?',
#  'What is the significance of the induction of Her2-specific CTLs by Hsp70L1-Her2(341-456)-pulsed DCs?',
#  'What are the challenges in the diagnosis and management of AOSD patients with complex clinical situations?',
#  'What is the significance of pretreatment of clinical specimens in glycine buffer pH 10.',
#  'What are the basic principles of medical management of rat colonies?',
#  'What is the significance of the reduced incidence of DGE in patients undergoing PD with RIGL?',
#  'What is the significance of the identified genes in circadian period determination?',
#  'What is the significance of the detected influenza C virus in the samples from children with ILI?',
#  'What is the significance of the National NBC Protection in Switzerland?',
#  'What is the significance of mesenchymal stem cell use in combating the inflammatory cascade in ARDS?',
#  'What are the prospects for discovering emerging viruses among wildlife, bats, rodents, arthropod vectors and occupationally exposed humans?',
#  'What is the significance of research collaboration network analysis in Hantavirus research?',
#  'What is the significance of the Fc-FcR interaction in the immunogenicity of Fc fusion proteins?',
#  'What is the significance of laparoscopic-assisted right extended hepatectomy for hilar cholangiocarcinoma with laparoscopically hand-sewn hepaticojejunostomy in select patients?',
#  'What is the significance of Pepitope in predicting discontinuous epitopes?',
#  'What is the significance of the combination of density modification procedures, automatic model building and bioinformatics tools applied to guide the tracing of the major capsid protein (MCP) of this virus?',
#  'What is the significance of ADAM17-mediated ACE2 shedding in hypertensive patients?',
#  'What is the significance of the technologische Ausstattung in the homeoffice?',
#  'What is the significance of understanding the delicate balance that exists between "immune altering" microbes that suppress immune responses during primary infections leading to severe secondary infections versus those infections found in patients with inborn errors of innate or adaptive immunity?',
#  'What is the significance of the identified broadly HIV-1-neutralizing human monoclonal antibodies (MAbs) in the design of effective vaccine immunogens?',
#  'What is the significance of insurance market development in promoting economic development?',
#  'What is the significance of the spatial distribution of Covid-19 cases in China?',
#  'What is the significance of ultraviolet radiation for disinfection?',
#  'What is the significance of the use of immunomodulatory biomaterials in the development of vaccines?',
#  'What is the significance of the interaction between coronaviruses and these cells in the pathogenesis of demyelination?',
#  'What are the advantages of using these technologies to facilitate communication, collaboration, education and scientific discourse?',
#  'What are the infectious diseases that may cause DAH in immunocompetent patients?',
#  'What are the techniques used to study antigen-specific B cell responses?',
#  'What is the significance of the discourse of preparedness in the context of pandemic influenza planning?',
#  'What are the implications of the fact that big data cannot deliver the promised revolution?',
#  'What is the significance of the characterisation of the context-freeness of a Word-MIX language?',
#  'What are the advantages of vaginal vault drainage after complicated SPA-LAVH?',
#  'What is the significance of the review of the parasites of the giant panda?',
#  '《What are the characteristics of DLI due to herbal medicine?》',
#  'What is the significance of the down-regulation of the transport gene cluster in the jejunum of rotavirus-infected piglets?',
#  'What is the significance of the nonmonotonic behavior of the vaccination coverage on the epidemic incidence?',
#  'What are the imaging features of parasitic infections of the thorax?',
#  'What is the significance of the cellular biology of hepatitis B virus infection in the pathogenesis of hepatitis B virus induced hepatocellular injury?',
#  'What is the significance of the proposed framework for mesh generation?',
#  'ƒ What is the significance of the pharmacological effects of licorice and its bioactive compounds?',
#  'What is the significance of inositol in the oviducts of turkey and hen?',
#  'What is the significance of emergence of drug-resistant variants in immunocompromised or immunologically naïve hosts?',
#  'What is the significance of the findings regarding prosocialness and relational-interdependent self-construal in relation to burnout among Swedish clergy?',
#  'What is the significance of the synthesis of amino acid conjugates of glycyrrhizic acid?',
#  'What is the significance of the comparison of three hypothetical alternative kitchen waste management systems?',
#  'What is the significance of the dispersion distance of exhaled air and aerosolized droplets during application of a jet nebulizer?',
#  'What is the importance of preserving biodiversity in the discovery of new drugs?',
#  'What is the significance of early diagnosis of HFS?',
#  'What is the significance of the cytokine response during pneumonia?',
#  'What is the significance of diagnosis and treatment of URTIs?',
#  'What is the significance of selective thrombus aspiration with the Penumbra system for the occluded central and precentral arteries distal to the non-occlusive dissecting lesion?',
#  'What is the significance of combining the specific and sensitive molecular detection of bacteria, viruses, fungi, and drug resistances?',
#  'What is the significance of the BLE communication protocol used in the healthcare context?',
#  'What is the significance of the discovery of a novel tick-borne phlebovirus in Tasmania?',
#  'What is the significance of efficient production of recombinant subviral particles containing native prM and E envelope proteins for all dengue serotypes?',
#  'What is the significance of the phylogeny of the deep‐sea cirripede family Scalpellidae?',
#  'What is the significance of the accuracy of the two navigation systems?',
#  'What is the significance of the low fecundity and high infant mortality in the North American captive cheetah population?',
#  'What is the significance of regional and national implementation efforts to control and eliminate dog-mediated rabies?',
#  'What is the significance of the use of small molecule inhibitors of CXCR4 and CCR5 in the study of neuroinflammatory diseases?']
