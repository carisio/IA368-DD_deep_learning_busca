# %% [markdown]
# A partir da saída da etapa anterior (arquivo sections-xxxx.pkl), carrega todos os artigos necessários em um mapa do tipo:
#
#     papers = {
#       "paperId": {
#         "metadata": OBJETO_RETORNADO_PELO_SEMANTIC_SCHOLAR,
#         "url": URL PARA O PDF DO ARTIGO,
#         "title": TÍTULO,
#         "abstract": ABSTRACT,
#         "text": TEXTO
#       }
#     }
#
#
# Observação: na prática, os dados de url/title/abstract podem ser acessados pelos metadados, mas vamos deixar no primeiro nível pra facilitar o acesso.

# %%
# Input file from last stage
file_sections_structure = 'sections-how to represent text for information retrieval-2010-2023.pkl'
# Output file with the contents of each paper
file_papers_contents = 'papers_contents-how to represent text for information retrieval-2010-2023.pkl'

folder_papers = './papers_pdf/'

# %%
# !pip install pypdfium2 -q

# !mkdir -p {folder_papers}
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 29.3 MB/s eta 0:00:00

# %%
# Para ser populado

papers = {}

# %%
import pickle
with open(file_sections_structure, "rb") as f:
   sections = pickle.load(f)

# %%
def download_pdf(paperId, url):
  print(f"Downloading paper {paperId}: {url}")
  # !wget {url} -O {folder_papers}{paperId}.pdf --user-agent="Mozilla" --tries=1 -T 5

# %%
import pypdfium2 as pdfium

def extract_text(paperId):
  pdf_file = f'{folder_papers}{paperId}.pdf'
  txt_contents = ''

  print(f"Extracting {paperId}")
  try:
    pdf = pdfium.PdfDocument(pdf_file)
    for i in range(len(pdf)):
      txt_contents += pdf[i].get_textpage().get_text_range()

    # Remove the break lines and considers only one big string of text:
    txt_contents = txt_contents.replace('\r\n', ' ')
    txt_contents = txt_contents.replace('\n', ' ')
    # Remove everything before introduction and reference section:
    txt_contents_lower = txt_contents.lower()
    idx_introduction = max(txt_contents_lower.find('introduction'), 0)
    idx_references = max(txt_contents_lower.rfind('reference'), 0)
    txt_contents = txt_contents[idx_introduction:idx_references]

    return txt_contents
  except:
    print(f'***** Problems with {pdf_file}. Ignoring...')
    return ''

# %%
def walk_sections_and_save_pdfs(list_of_sections):
  for section in list_of_sections:
    papers_of_section = section['papers']

    for paper in papers_of_section:
      paperId = paper['paperId']
      url = paper['openAccessPdf']['url']
      if paperId not in papers:
        download_pdf(paperId, url)
        text = extract_text(paperId)
        papers[paperId] = {
          "metadata": paper,
          "url": url,
          "title": paper['title'],
          "abstract": paper['abstract'],
          "text": text
        }
        walk_sections_and_save_pdfs(section['subsections'])

# %%
# %%time

papers = {}
walk_sections_and_save_pdfs(sections)
# Out:
# Downloading paper a5ac8ff1f9a5ae7a9a6650e1908c7f44614b1d23: http://hal.inria.fr/docs/00/72/18/06/PDF/MoDRE2012_Sannier_Baudry_Multilevel_Requirements_Traceability_Using_MDE_and_IR-cr3.pdf
# --2023-06-27 10:52:37--  http://hal.inria.fr/docs/00/72/18/06/PDF/MoDRE2012_Sannier_Baudry_Multilevel_Requirements_Traceability_Using_MDE_and_IR-cr3.pdf
# Resolving hal.inria.fr (hal.inria.fr)... 193.48.96.10
# Connecting to hal.inria.fr (hal.inria.fr)|193.48.96.10|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://inria.hal.science/docs/00/72/18/06/PDF/MoDRE2012_Sannier_Baudry_Multilevel_Requirements_Traceability_Using_MDE_and_IR-cr3.pdf [following]
# --2023-06-27 10:52:39--  https://inria.hal.science/docs/00/72/18/06/PDF/MoDRE2012_Sannier_Baudry_Multilevel_Requirements_Traceability_Using_MDE_and_IR-cr3.pdf
# Resolving inria.hal.science (inria.hal.science)... 193.48.96.10
# Connecting to inria.hal.science (inria.hal.science)|193.48.96.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /file/index/docid/721806/filename/MoDRE2012_Sannier_Baudry_Multilevel_Requirements_Traceability_Using_MDE_and_IR-cr3.pdf [following]
# --2023-06-27 10:52:40--  https://inria.hal.science/file/index/docid/721806/filename/MoDRE2012_Sannier_Baudry_Multilevel_Requirements_Traceability_Using_MDE_and_IR-cr3.pdf
# Reusing existing connection to inria.hal.science:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 723782 (707K) [application/pdf]
# Saving to: ‘./papers_pdf/a5ac8ff1f9a5ae7a9a6650e1908c7f44614b1d23.pdf’
#
# ./papers_pdf/a5ac8f 100%[===================>] 706.82K   575KB/s    in 1.2s
#
# 2023-06-27 10:52:42 (575 KB/s) - ‘./papers_pdf/a5ac8ff1f9a5ae7a9a6650e1908c7f44614b1d23.pdf’ saved [723782/723782]
#
# Extracting a5ac8ff1f9a5ae7a9a6650e1908c7f44614b1d23
# Downloading paper 20381cd41140b547d54899b69424b69d0de567e0: https://www.mdpi.com/2078-2489/13/8/368/pdf?version=1661314600
# --2023-06-27 10:52:42--  https://www.mdpi.com/2078-2489/13/8/368/pdf?version=1661314600
# Resolving www.mdpi.com (www.mdpi.com)... 104.18.24.151, 104.18.25.151
# Connecting to www.mdpi.com (www.mdpi.com)|104.18.24.151|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://mdpi-res.com/d_attachment/information/information-13-00368/article_deploy/information-13-00368-v2.pdf?version=1661314600 [following]
# --2023-06-27 10:52:43--  https://mdpi-res.com/d_attachment/information/information-13-00368/article_deploy/information-13-00368-v2.pdf?version=1661314600
# Resolving mdpi-res.com (mdpi-res.com)... 172.67.68.164, 104.26.15.90, 104.26.14.90, ...
# Connecting to mdpi-res.com (mdpi-res.com)|172.67.68.164|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1694849 (1.6M) [application/pdf]
# Saving to: ‘./papers_pdf/20381cd41140b547d54899b69424b69d0de567e0.pdf’
#
# ./papers_pdf/20381c 100%[===================>]   1.62M  --.-KB/s    in 0.1s
#
# 2023-06-27 10:52:43 (12.7 MB/s) - ‘./papers_pdf/20381cd41140b547d54899b69424b69d0de567e0.pdf’ saved [1694849/1694849]
#
# Extracting 20381cd41140b547d54899b69424b69d0de567e0
# Downloading paper 0c01ed865fe6793aa526c9adb795736e3b2f2113: https://ijai.iaescore.com/index.php/IJAI/article/download/22123/13574
# --2023-06-27 10:52:43--  https://ijai.iaescore.com/index.php/IJAI/article/download/22123/13574
# Resolving ijai.iaescore.com (ijai.iaescore.com)... 68.178.229.197
# Connecting to ijai.iaescore.com (ijai.iaescore.com)|68.178.229.197|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 671047 (655K) [application/pdf]
# Saving to: ‘./papers_pdf/0c01ed865fe6793aa526c9adb795736e3b2f2113.pdf’
#
# ./papers_pdf/0c01ed 100%[===================>] 655.32K   843KB/s    in 0.8s
#
# 2023-06-27 10:52:45 (843 KB/s) - ‘./papers_pdf/0c01ed865fe6793aa526c9adb795736e3b2f2113.pdf’ saved [671047/671047]
#
# Extracting 0c01ed865fe6793aa526c9adb795736e3b2f2113
# Downloading paper a246d0d4093c798d300ea96a5645b2aa21c022a0: https://www.frontiersin.org/articles/10.3389/frma.2022.911070/pdf
# --2023-06-27 10:52:45--  https://www.frontiersin.org/articles/10.3389/frma.2022.911070/pdf
# Resolving www.frontiersin.org (www.frontiersin.org)... 13.107.246.73, 13.107.213.73, 2620:1ec:bdf::73, ...
# Connecting to www.frontiersin.org (www.frontiersin.org)|13.107.246.73|:443... connected.
# Unable to establish SSL connection.
# Extracting a246d0d4093c798d300ea96a5645b2aa21c022a0
# ***** Problems with ./papers_pdf/a246d0d4093c798d300ea96a5645b2aa21c022a0.pdf. Ignoring...
# Downloading paper d018efda7a49c03955f5b62c11d6de5c5725f8bc: http://oro.open.ac.uk/24736/1/ReiterWilliamschap09.pdf
# --2023-06-27 10:52:45--  http://oro.open.ac.uk/24736/1/ReiterWilliamschap09.pdf
# Resolving oro.open.ac.uk (oro.open.ac.uk)... 137.108.200.18
# Connecting to oro.open.ac.uk (oro.open.ac.uk)|137.108.200.18|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 914265 (893K) [application/pdf]
# Saving to: ‘./papers_pdf/d018efda7a49c03955f5b62c11d6de5c5725f8bc.pdf’
#
# ./papers_pdf/d018ef 100%[===================>] 892.84K   128KB/s    in 12s
#
# 2023-06-27 10:52:58 (76.0 KB/s) - ‘./papers_pdf/d018efda7a49c03955f5b62c11d6de5c5725f8bc.pdf’ saved [914265/914265]
#
# Extracting d018efda7a49c03955f5b62c11d6de5c5725f8bc
# Downloading paper 2c40b968cf53d4a82f6d603253a16f413b82c3e8: https://ieeexplore.ieee.org/ielx7/6287639/6514899/09868019.pdf
# --2023-06-27 10:52:58--  https://ieeexplore.ieee.org/ielx7/6287639/6514899/09868019.pdf
# Resolving ieeexplore.ieee.org (ieeexplore.ieee.org)... 184.26.213.169, 2600:1417:e800:18c::603, 2600:1417:e800:18b::603
# Connecting to ieeexplore.ieee.org (ieeexplore.ieee.org)|184.26.213.169|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2364876 (2.3M) [application/pdf]
# Saving to: ‘./papers_pdf/2c40b968cf53d4a82f6d603253a16f413b82c3e8.pdf’
#
# ./papers_pdf/2c40b9 100%[===================>]   2.25M   281KB/s    in 8.4s
#
# 2023-06-27 10:53:07 (276 KB/s) - ‘./papers_pdf/2c40b968cf53d4a82f6d603253a16f413b82c3e8.pdf’ saved [2364876/2364876]
#
# Extracting 2c40b968cf53d4a82f6d603253a16f413b82c3e8
# Downloading paper f44370126c8cd4f1ab0fe2832d3f9a6fa6b6f3cc: https://download.atlantis-press.com/article/25870557.pdf
# --2023-06-27 10:53:07--  https://download.atlantis-press.com/article/25870557.pdf
# Resolving download.atlantis-press.com (download.atlantis-press.com)... 136.144.178.116
# Connecting to download.atlantis-press.com (download.atlantis-press.com)|136.144.178.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1930084 (1.8M) [application/pdf]
# Saving to: ‘./papers_pdf/f44370126c8cd4f1ab0fe2832d3f9a6fa6b6f3cc.pdf’
#
# ./papers_pdf/f44370 100%[===================>]   1.84M  1.22MB/s    in 1.5s
#
# 2023-06-27 10:53:10 (1.22 MB/s) - ‘./papers_pdf/f44370126c8cd4f1ab0fe2832d3f9a6fa6b6f3cc.pdf’ saved [1930084/1930084]
#
# Extracting f44370126c8cd4f1ab0fe2832d3f9a6fa6b6f3cc
# Downloading paper f38237fa10da8bac34fa84fd63aa3dc254812ff6: https://journal.acs.org.au/index.php/ajis/article/download/1701/827
# --2023-06-27 10:53:10--  https://journal.acs.org.au/index.php/ajis/article/download/1701/827
# Resolving journal.acs.org.au (journal.acs.org.au)... 104.26.11.230, 104.26.10.230, 172.67.69.233, ...
# Connecting to journal.acs.org.au (journal.acs.org.au)|104.26.11.230|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1051272 (1.0M) [application/pdf]
# Saving to: ‘./papers_pdf/f38237fa10da8bac34fa84fd63aa3dc254812ff6.pdf’
#
# ./papers_pdf/f38237 100%[===================>]   1.00M  1.11MB/s    in 0.9s
#
# 2023-06-27 10:53:13 (1.11 MB/s) - ‘./papers_pdf/f38237fa10da8bac34fa84fd63aa3dc254812ff6.pdf’ saved [1051272/1051272]
#
# Extracting f38237fa10da8bac34fa84fd63aa3dc254812ff6
# Downloading paper 64e63f5b5613de74831bd29bc8983f92be1fc8bc: http://thesai.org/Downloads/Volume11No6/Paper_80-Document_Classification_Method_based_on_Graphs.pdf
# --2023-06-27 10:53:13--  http://thesai.org/Downloads/Volume11No6/Paper_80-Document_Classification_Method_based_on_Graphs.pdf
# Resolving thesai.org (thesai.org)... 104.21.53.91, 172.67.211.13, 2606:4700:3036::6815:355b, ...
# Connecting to thesai.org (thesai.org)|104.21.53.91|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thesai.org/Downloads/Volume11No6/Paper_80-Document_Classification_Method_based_on_Graphs.pdf [following]
# --2023-06-27 10:53:13--  https://thesai.org/Downloads/Volume11No6/Paper_80-Document_Classification_Method_based_on_Graphs.pdf
# Connecting to thesai.org (thesai.org)|104.21.53.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1103236 (1.1M) [application/pdf]
# Saving to: ‘./papers_pdf/64e63f5b5613de74831bd29bc8983f92be1fc8bc.pdf’
#
# ./papers_pdf/64e63f 100%[===================>]   1.05M  --.-KB/s    in 0.08s
#
# 2023-06-27 10:53:13 (12.8 MB/s) - ‘./papers_pdf/64e63f5b5613de74831bd29bc8983f92be1fc8bc.pdf’ saved [1103236/1103236]
#
# Extracting 64e63f5b5613de74831bd29bc8983f92be1fc8bc
# Downloading paper f3cc9d54c5bd1672a3dad370897834ac3967b2ff: http://arxiv.org/pdf/1503.06776
# --2023-06-27 10:53:14--  http://arxiv.org/pdf/1503.06776
# Resolving arxiv.org (arxiv.org)... 128.84.21.199
# Connecting to arxiv.org (arxiv.org)|128.84.21.199|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://arxiv.org/pdf/1503.06776 [following]
# --2023-06-27 10:53:14--  https://arxiv.org/pdf/1503.06776
# Connecting to arxiv.org (arxiv.org)|128.84.21.199|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://arxiv.org/pdf/1503.06776.pdf [following]
# --2023-06-27 10:53:15--  https://arxiv.org/pdf/1503.06776.pdf
# Reusing existing connection to arxiv.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1134121 (1.1M) [application/pdf]
# Saving to: ‘./papers_pdf/f3cc9d54c5bd1672a3dad370897834ac3967b2ff.pdf’
#
# ./papers_pdf/f3cc9d 100%[===================>]   1.08M   368KB/s    in 3.0s
#
# 2023-06-27 10:53:18 (368 KB/s) - ‘./papers_pdf/f3cc9d54c5bd1672a3dad370897834ac3967b2ff.pdf’ saved [1134121/1134121]
#
# Extracting f3cc9d54c5bd1672a3dad370897834ac3967b2ff
# Downloading paper 6e8c87b244faa88c396c78c85568e69ed08d17fe: https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/pra2.2015.1450520100122
# --2023-06-27 10:53:18--  https://onlinelibrary.wiley.com/doi/pdfdirect/10.1002/pra2.2015.1450520100122
# Resolving onlinelibrary.wiley.com (onlinelibrary.wiley.com)... 162.159.130.87, 162.159.129.87, 2606:4700:7::a29f:8257, ...
# Connecting to onlinelibrary.wiley.com (onlinelibrary.wiley.com)|162.159.130.87|:443... connected.
# HTTP request sent, awaiting response... 403 Forbidden
# 2023-06-27 10:53:19 ERROR 403: Forbidden.
#
# Extracting 6e8c87b244faa88c396c78c85568e69ed08d17fe
# ***** Problems with ./papers_pdf/6e8c87b244faa88c396c78c85568e69ed08d17fe.pdf. Ignoring...
# Downloading paper e26acb19824738c1ce8364d87b35914393649d31: https://rke.abertay.ac.uk/ws/files/16676957/Renaud_AFrameworkForInterrogatingSocialMediaImages_Accepted_2019.pdf
# --2023-06-27 10:53:19--  https://rke.abertay.ac.uk/ws/files/16676957/Renaud_AFrameworkForInterrogatingSocialMediaImages_Accepted_2019.pdf
# Resolving rke.abertay.ac.uk (rke.abertay.ac.uk)... 34.248.98.230, 54.74.68.52, 34.253.178.11
# Connecting to rke.abertay.ac.uk (rke.abertay.ac.uk)|34.248.98.230|:443... connected.
# HTTP request sent, awaiting response... 200 200
# Length: 2524022 (2.4M) [application/pdf]
# Saving to: ‘./papers_pdf/e26acb19824738c1ce8364d87b35914393649d31.pdf’
#
# ./papers_pdf/e26acb 100%[===================>]   2.41M  1.35MB/s    in 1.8s
#
# 2023-06-27 10:53:22 (1.35 MB/s) - ‘./papers_pdf/e26acb19824738c1ce8364d87b35914393649d31.pdf’ saved [2524022/2524022]
#
# Extracting e26acb19824738c1ce8364d87b35914393649d31
# Downloading paper af43de01456a26a9a237ceeebb80292fae523ec6: https://doi.org/10.9790/0661-16131721
# --2023-06-27 10:53:23--  https://doi.org/10.9790/0661-16131721
# Resolving doi.org (doi.org)... 104.26.9.237, 104.26.8.237, 172.67.72.147, ...
# Connecting to doi.org (doi.org)|104.26.9.237|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://www.iosrjournals.org/iosr-jce/papers/Vol16-issue1/Version-3/D016131721.pdf [following]
# --2023-06-27 10:53:23--  http://www.iosrjournals.org/iosr-jce/papers/Vol16-issue1/Version-3/D016131721.pdf
# Resolving www.iosrjournals.org (www.iosrjournals.org)... 49.50.81.200
# Connecting to www.iosrjournals.org (www.iosrjournals.org)|49.50.81.200|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 131960 (129K) [application/pdf]
# Saving to: ‘./papers_pdf/af43de01456a26a9a237ceeebb80292fae523ec6.pdf’
#
# ./papers_pdf/af43de 100%[===================>] 128.87K   323KB/s    in 0.4s
#
# 2023-06-27 10:53:24 (323 KB/s) - ‘./papers_pdf/af43de01456a26a9a237ceeebb80292fae523ec6.pdf’ saved [131960/131960]
#
# Extracting af43de01456a26a9a237ceeebb80292fae523ec6
# Downloading paper 0767eb5ab61d25920bc4046b3baab6ee5c6d5cfa: https://bmcmedinformdecismak.biomedcentral.com/track/pdf/10.1186/s12911-021-01724-2
# --2023-06-27 10:53:24--  https://bmcmedinformdecismak.biomedcentral.com/track/pdf/10.1186/s12911-021-01724-2
# Resolving bmcmedinformdecismak.biomedcentral.com (bmcmedinformdecismak.biomedcentral.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to bmcmedinformdecismak.biomedcentral.com (bmcmedinformdecismak.biomedcentral.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://bmcmedinformdecismak.biomedcentral.com/counter/pdf/10.1186/s12911-021-01724-2.pdf [following]
# --2023-06-27 10:53:25--  https://bmcmedinformdecismak.biomedcentral.com/counter/pdf/10.1186/s12911-021-01724-2.pdf
# Reusing existing connection to bmcmedinformdecismak.biomedcentral.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5122615 (4.9M) [application/pdf]
# Saving to: ‘./papers_pdf/0767eb5ab61d25920bc4046b3baab6ee5c6d5cfa.pdf’
#
# ./papers_pdf/0767eb 100%[===================>]   4.88M  --.-KB/s    in 0.1s
#
# 2023-06-27 10:53:28 (49.3 MB/s) - ‘./papers_pdf/0767eb5ab61d25920bc4046b3baab6ee5c6d5cfa.pdf’ saved [5122615/5122615]
#
# Extracting 0767eb5ab61d25920bc4046b3baab6ee5c6d5cfa
# Downloading paper c602c00faf49044f68dbc62da200564b171d2455: https://scholarworks.boisestate.edu/cgi/viewcontent.cgi?article=2652&context=td
# /bin/bash: -O: command not found
# --2023-06-27 10:53:28--  https://scholarworks.boisestate.edu/cgi/viewcontent.cgi?article=2652
# Resolving scholarworks.boisestate.edu (scholarworks.boisestate.edu)... 50.18.241.247, 13.57.92.51
# Connecting to scholarworks.boisestate.edu (scholarworks.boisestate.edu)|50.18.241.247|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2023-06-27 10:53:29 ERROR 400: Bad Request.
#
# Extracting c602c00faf49044f68dbc62da200564b171d2455
# ***** Problems with ./papers_pdf/c602c00faf49044f68dbc62da200564b171d2455.pdf. Ignoring...
# Downloading paper 09cdc6bcd057e38746d08e2a74d40a6ca9630484: http://jsju.org/index.php/journal/article/download/296/294
# --2023-06-27 10:53:29--  http://jsju.org/index.php/journal/article/download/296/294
# Resolving jsju.org (jsju.org)... 88.212.232.164
# Connecting to jsju.org (jsju.org)|88.212.232.164|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 968020 (945K) [application/pdf]
# Saving to: ‘./papers_pdf/09cdc6bcd057e38746d08e2a74d40a6ca9630484.pdf’
#
# ./papers_pdf/09cdc6 100%[===================>] 945.33K   552KB/s    in 1.7s
#
# 2023-06-27 10:53:32 (552 KB/s) - ‘./papers_pdf/09cdc6bcd057e38746d08e2a74d40a6ca9630484.pdf’ saved [968020/968020]
#
# Extracting 09cdc6bcd057e38746d08e2a74d40a6ca9630484
# Downloading paper 09de817e0552bed0cf47f262e8476c87a601109a: http://www.nomos-elibrary.de/10.5771/0943-7444-2017-6-416.pdf
# --2023-06-27 10:53:32--  http://www.nomos-elibrary.de/10.5771/0943-7444-2017-6-416.pdf
# Resolving www.nomos-elibrary.de (www.nomos-elibrary.de)... 185.105.252.114
# Connecting to www.nomos-elibrary.de (www.nomos-elibrary.de)|185.105.252.114|:80... failed: Connection refused.
# Extracting 09de817e0552bed0cf47f262e8476c87a601109a
# ***** Problems with ./papers_pdf/09de817e0552bed0cf47f262e8476c87a601109a.pdf. Ignoring...
# Downloading paper 95ee6dbaf9bb4ef6a9808366e552b400ad48dbc0: https://download.atlantis-press.com/article/25860912.pdf
# --2023-06-27 10:53:34--  https://download.atlantis-press.com/article/25860912.pdf
# Resolving download.atlantis-press.com (download.atlantis-press.com)... 136.144.178.116
# Connecting to download.atlantis-press.com (download.atlantis-press.com)|136.144.178.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1405512 (1.3M) [application/pdf]
# Saving to: ‘./papers_pdf/95ee6dbaf9bb4ef6a9808366e552b400ad48dbc0.pdf’
#
# ./papers_pdf/95ee6d 100%[===================>]   1.34M  1.06MB/s    in 1.3s
#
# 2023-06-27 10:53:36 (1.06 MB/s) - ‘./papers_pdf/95ee6dbaf9bb4ef6a9808366e552b400ad48dbc0.pdf’ saved [1405512/1405512]
#
# Extracting 95ee6dbaf9bb4ef6a9808366e552b400ad48dbc0
# Downloading paper 4b368954e4a5fcf997cbd590a52b292e185af071: https://digitalcommons.fiu.edu/cgi/viewcontent.cgi?article=3368&context=etd
# --2023-06-27 10:53:36--  https://digitalcommons.fiu.edu/cgi/viewcontent.cgi?article=3368
# /bin/bash: -O: command not found
# Resolving digitalcommons.fiu.edu (digitalcommons.fiu.edu)... 13.57.92.51, 50.18.241.247
# Connecting to digitalcommons.fiu.edu (digitalcommons.fiu.edu)|13.57.92.51|:443... connected.
# HTTP request sent, awaiting response... 400 Bad Request
# 2023-06-27 10:53:38 ERROR 400: Bad Request.
#
# Extracting 4b368954e4a5fcf997cbd590a52b292e185af071
# ***** Problems with ./papers_pdf/4b368954e4a5fcf997cbd590a52b292e185af071.pdf. Ignoring...
# Downloading paper 7c72a2008f94078ce50ac251c6437038bbcf0185: https://kops.uni-konstanz.de/bitstream/123456789/37472/1/Schwarzer_2-1unn74ajzyyz15.pdf
# --2023-06-27 10:53:38--  https://kops.uni-konstanz.de/bitstream/123456789/37472/1/Schwarzer_2-1unn74ajzyyz15.pdf
# Resolving kops.uni-konstanz.de (kops.uni-konstanz.de)... 134.34.33.16
# Connecting to kops.uni-konstanz.de (kops.uni-konstanz.de)|134.34.33.16|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://kops.uni-konstanz.de/server/api/core/bitstreams/07d8ca6c-fbb0-4ec3-86d4-0f0e6c770e0f/content [following]
# --2023-06-27 10:53:39--  https://kops.uni-konstanz.de/server/api/core/bitstreams/07d8ca6c-fbb0-4ec3-86d4-0f0e6c770e0f/content
# Reusing existing connection to kops.uni-konstanz.de:443.
# HTTP request sent, awaiting response... 200 200
# Length: 185984 (182K) [application/pdf]
# Saving to: ‘./papers_pdf/7c72a2008f94078ce50ac251c6437038bbcf0185.pdf’
#
# ./papers_pdf/7c72a2 100%[===================>] 181.62K   238KB/s    in 0.8s
#
# 2023-06-27 10:53:42 (238 KB/s) - ‘./papers_pdf/7c72a2008f94078ce50ac251c6437038bbcf0185.pdf’ saved [185984/185984]
#
# Extracting 7c72a2008f94078ce50ac251c6437038bbcf0185
# Downloading paper b030ceb178313e4e1d1321119c2460428558a5d0: https://helda.helsinki.fi/bitstream/10138/313970/1/huang_2019_1.pdf
# --2023-06-27 10:53:42--  https://helda.helsinki.fi/bitstream/10138/313970/1/huang_2019_1.pdf
# Resolving helda.helsinki.fi (helda.helsinki.fi)... 128.214.205.103
# Connecting to helda.helsinki.fi (helda.helsinki.fi)|128.214.205.103|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /bitstream/handle/10138/313970/huang_2019_1.pdf;jsessionid=F09D62C4CC2B4F80A5F40354C73EFA6F?sequence=1 [following]
# --2023-06-27 10:53:44--  https://helda.helsinki.fi/bitstream/handle/10138/313970/huang_2019_1.pdf;jsessionid=F09D62C4CC2B4F80A5F40354C73EFA6F?sequence=1
# Reusing existing connection to helda.helsinki.fi:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 668411 (653K) [application/pdf]
# Saving to: ‘./papers_pdf/b030ceb178313e4e1d1321119c2460428558a5d0.pdf’
#
# ./papers_pdf/b030ce 100%[===================>] 652.75K   469KB/s    in 1.4s
#
# 2023-06-27 10:53:46 (469 KB/s) - ‘./papers_pdf/b030ceb178313e4e1d1321119c2460428558a5d0.pdf’ saved [668411/668411]
#
# Extracting b030ceb178313e4e1d1321119c2460428558a5d0
# ***** Problems with ./papers_pdf/b030ceb178313e4e1d1321119c2460428558a5d0.pdf. Ignoring...
# Downloading paper 8483632dd1bbab0516f7104a70995d05045615f1: https://doi.org/10.47893/ijcct.2010.1033
# --2023-06-27 10:53:46--  https://doi.org/10.47893/ijcct.2010.1033
# Resolving doi.org (doi.org)... 104.26.9.237, 104.26.8.237, 172.67.72.147, ...
# Connecting to doi.org (doi.org)|104.26.9.237|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.interscience.in/cgi/viewcontent.cgi?article=1033&context=ijcct [following]
# --2023-06-27 10:53:46--  https://www.interscience.in/cgi/viewcontent.cgi?article=1033&context=ijcct
# Resolving www.interscience.in (www.interscience.in)... 13.57.92.51, 50.18.241.247
# Connecting to www.interscience.in (www.interscience.in)|13.57.92.51|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 388144 (379K) [application/pdf]
# Saving to: ‘./papers_pdf/8483632dd1bbab0516f7104a70995d05045615f1.pdf’
#
# ./papers_pdf/848363 100%[===================>] 379.05K   678KB/s    in 0.6s
#
# 2023-06-27 10:53:48 (678 KB/s) - ‘./papers_pdf/8483632dd1bbab0516f7104a70995d05045615f1.pdf’ saved [388144/388144]
#
# Extracting 8483632dd1bbab0516f7104a70995d05045615f1
# Downloading paper e7d7dc15e7327d0b9b01d2987c63383c53325d50: https://www.frontiersin.org/articles/10.3389/fdata.2021.779792/pdf
# --2023-06-27 10:53:48--  https://www.frontiersin.org/articles/10.3389/fdata.2021.779792/pdf
# Resolving www.frontiersin.org (www.frontiersin.org)... 13.107.246.73, 13.107.213.73, 2620:1ec:bdf::73, ...
# Connecting to www.frontiersin.org (www.frontiersin.org)|13.107.246.73|:443... connected.
# Unable to establish SSL connection.
# Extracting e7d7dc15e7327d0b9b01d2987c63383c53325d50
# ***** Problems with ./papers_pdf/e7d7dc15e7327d0b9b01d2987c63383c53325d50.pdf. Ignoring...
# Downloading paper 3ca2499d5b00c21f12b8717e3c25a5d00a0aeb41: https://link.springer.com/content/pdf/10.1007%2F978-3-642-13489-0_9.pdf
# --2023-06-27 10:53:48--  https://link.springer.com/content/pdf/10.1007%2F978-3-642-13489-0_9.pdf
# Resolving link.springer.com (link.springer.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to link.springer.com (link.springer.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://link.springer.com/content/pdf/10.1007/978-3-642-13489-0_9.pdf [following]
# --2023-06-27 10:53:49--  https://link.springer.com/content/pdf/10.1007/978-3-642-13489-0_9.pdf
# Reusing existing connection to link.springer.com:443.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://idp.springer.com/authorize?response_type=cookie&client_id=springerlink&redirect_uri=https%3A%2F%2Flink.springer.com%2Fcontent%2Fpdf%2F10.1007%2F978-3-642-13489-0_9.pdf [following]
# --2023-06-27 10:53:49--  https://idp.springer.com/authorize?response_type=cookie&client_id=springerlink&redirect_uri=https%3A%2F%2Flink.springer.com%2Fcontent%2Fpdf%2F10.1007%2F978-3-642-13489-0_9.pdf
# Resolving idp.springer.com (idp.springer.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to idp.springer.com (idp.springer.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://link.springer.com/content/pdf/10.1007/978-3-642-13489-0_9.pdf [following]
# --2023-06-27 10:53:49--  https://link.springer.com/content/pdf/10.1007/978-3-642-13489-0_9.pdf
# Connecting to link.springer.com (link.springer.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 244352 (239K) [application/pdf]
# Saving to: ‘./papers_pdf/3ca2499d5b00c21f12b8717e3c25a5d00a0aeb41.pdf’
#
# ./papers_pdf/3ca249 100%[===================>] 238.62K  --.-KB/s    in 0.03s
#
# 2023-06-27 10:53:51 (7.42 MB/s) - ‘./papers_pdf/3ca2499d5b00c21f12b8717e3c25a5d00a0aeb41.pdf’ saved [244352/244352]
#
# Extracting 3ca2499d5b00c21f12b8717e3c25a5d00a0aeb41
# Downloading paper 3e45b7dbe1f12ea0110fa5bb7609aa90b33c20d9: http://arxiv.org/pdf/1608.00758
# URL transformed to HTTPS due to an HSTS policy
# --2023-06-27 10:53:51--  https://arxiv.org/pdf/1608.00758
# Resolving arxiv.org (arxiv.org)... 128.84.21.199
# Connecting to arxiv.org (arxiv.org)|128.84.21.199|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://arxiv.org/pdf/1608.00758.pdf [following]
# --2023-06-27 10:53:52--  https://arxiv.org/pdf/1608.00758.pdf
# Reusing existing connection to arxiv.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 438879 (429K) [application/pdf]
# Saving to: ‘./papers_pdf/3e45b7dbe1f12ea0110fa5bb7609aa90b33c20d9.pdf’
#
# ./papers_pdf/3e45b7 100%[===================>] 428.59K   462KB/s    in 0.9s
#
# 2023-06-27 10:53:54 (462 KB/s) - ‘./papers_pdf/3e45b7dbe1f12ea0110fa5bb7609aa90b33c20d9.pdf’ saved [438879/438879]
#
# Extracting 3e45b7dbe1f12ea0110fa5bb7609aa90b33c20d9
# Downloading paper 5624ee3a16da7c77bf9eee491516939acf2862a6: http://www.cse.lehigh.edu/~huang/kim-etal_finalspie2011.pdf
# --2023-06-27 10:53:54--  http://www.cse.lehigh.edu/~huang/kim-etal_finalspie2011.pdf
# Resolving www.cse.lehigh.edu (www.cse.lehigh.edu)... 128.180.120.45
# Connecting to www.cse.lehigh.edu (www.cse.lehigh.edu)|128.180.120.45|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5236923 (5.0M) [application/pdf]
# Saving to: ‘./papers_pdf/5624ee3a16da7c77bf9eee491516939acf2862a6.pdf’
#
# ./papers_pdf/5624ee 100%[===================>]   4.99M  1.23MB/s    in 5.5s
#
# 2023-06-27 10:54:00 (924 KB/s) - ‘./papers_pdf/5624ee3a16da7c77bf9eee491516939acf2862a6.pdf’ saved [5236923/5236923]
#
# Extracting 5624ee3a16da7c77bf9eee491516939acf2862a6
# Downloading paper 6c318926ec149a5e1a17599e67cc70d85e09a9a0: http://thesai.org/Downloads/Volume12No2/Paper_54-Verb_Sense_Disambiguation.pdf
# --2023-06-27 10:54:00--  http://thesai.org/Downloads/Volume12No2/Paper_54-Verb_Sense_Disambiguation.pdf
# Resolving thesai.org (thesai.org)... 104.21.53.91, 172.67.211.13, 2606:4700:3033::ac43:d30d, ...
# Connecting to thesai.org (thesai.org)|104.21.53.91|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thesai.org/Downloads/Volume12No2/Paper_54-Verb_Sense_Disambiguation.pdf [following]
# --2023-06-27 10:54:00--  https://thesai.org/Downloads/Volume12No2/Paper_54-Verb_Sense_Disambiguation.pdf
# Connecting to thesai.org (thesai.org)|104.21.53.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 552047 (539K) [application/pdf]
# Saving to: ‘./papers_pdf/6c318926ec149a5e1a17599e67cc70d85e09a9a0.pdf’
#
# ./papers_pdf/6c3189 100%[===================>] 539.11K  1.10MB/s    in 0.5s
#
# 2023-06-27 10:54:02 (1.10 MB/s) - ‘./papers_pdf/6c318926ec149a5e1a17599e67cc70d85e09a9a0.pdf’ saved [552047/552047]
#
# Extracting 6c318926ec149a5e1a17599e67cc70d85e09a9a0
# Downloading paper 615e1b09fcf3d2f6010aed0ef5e70275882bcd22: https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0027499&type=printable
# /bin/bash: -O: command not found
# --2023-06-27 10:54:02--  https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0027499
# Resolving journals.plos.org (journals.plos.org)... 35.190.43.188
# Connecting to journals.plos.org (journals.plos.org)|35.190.43.188|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-06-27 10:54:02 ERROR 404: Not Found.
#
# Extracting 615e1b09fcf3d2f6010aed0ef5e70275882bcd22
# ***** Problems with ./papers_pdf/615e1b09fcf3d2f6010aed0ef5e70275882bcd22.pdf. Ignoring...
# Downloading paper 01657e073dbb39d5c0ffeccb85e5b239c0e35ff1: http://thesai.org/Downloads/Volume6No2/Paper_42-Similarity_Calculation_Method_of_Chinese_Short_Text_Based_on_Semantic_Feature_Space.pdf
# --2023-06-27 10:54:02--  http://thesai.org/Downloads/Volume6No2/Paper_42-Similarity_Calculation_Method_of_Chinese_Short_Text_Based_on_Semantic_Feature_Space.pdf
# Resolving thesai.org (thesai.org)... 104.21.53.91, 172.67.211.13, 2606:4700:3033::ac43:d30d, ...
# Connecting to thesai.org (thesai.org)|104.21.53.91|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://thesai.org/Downloads/Volume6No2/Paper_42-Similarity_Calculation_Method_of_Chinese_Short_Text_Based_on_Semantic_Feature_Space.pdf [following]
# --2023-06-27 10:54:02--  https://thesai.org/Downloads/Volume6No2/Paper_42-Similarity_Calculation_Method_of_Chinese_Short_Text_Based_on_Semantic_Feature_Space.pdf
# Connecting to thesai.org (thesai.org)|104.21.53.91|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 464670 (454K) [application/pdf]
# Saving to: ‘./papers_pdf/01657e073dbb39d5c0ffeccb85e5b239c0e35ff1.pdf’
#
# ./papers_pdf/01657e 100%[===================>] 453.78K  1.43MB/s    in 0.3s
#
# 2023-06-27 10:54:03 (1.43 MB/s) - ‘./papers_pdf/01657e073dbb39d5c0ffeccb85e5b239c0e35ff1.pdf’ saved [464670/464670]
#
# Extracting 01657e073dbb39d5c0ffeccb85e5b239c0e35ff1
# Downloading paper 5160254e9dd5d6c0006f113a5784467eedd449e0: https://bmcmedinformdecismak.biomedcentral.com/track/pdf/10.1186/s12911-019-0784-1
# --2023-06-27 10:54:03--  https://bmcmedinformdecismak.biomedcentral.com/track/pdf/10.1186/s12911-019-0784-1
# Resolving bmcmedinformdecismak.biomedcentral.com (bmcmedinformdecismak.biomedcentral.com)... 151.101.0.95, 151.101.64.95, 151.101.128.95, ...
# Connecting to bmcmedinformdecismak.biomedcentral.com (bmcmedinformdecismak.biomedcentral.com)|151.101.0.95|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://bmcmedinformdecismak.biomedcentral.com/counter/pdf/10.1186/s12911-019-0784-1.pdf [following]
# --2023-06-27 10:54:04--  https://bmcmedinformdecismak.biomedcentral.com/counter/pdf/10.1186/s12911-019-0784-1.pdf
# Reusing existing connection to bmcmedinformdecismak.biomedcentral.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 473191 (462K) [application/pdf]
# Saving to: ‘./papers_pdf/5160254e9dd5d6c0006f113a5784467eedd449e0.pdf’
#
# ./papers_pdf/516025 100%[===================>] 462.10K  --.-KB/s    in 0.04s
#
# 2023-06-27 10:54:07 (10.3 MB/s) - ‘./papers_pdf/5160254e9dd5d6c0006f113a5784467eedd449e0.pdf’ saved [473191/473191]
#
# Extracting 5160254e9dd5d6c0006f113a5784467eedd449e0
# Downloading paper 7c6dd680030a3111409c45dfc28b1d9feebc25e3: https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0173152&type=printable
# /bin/bash: -O: command not found
# --2023-06-27 10:54:07--  https://journals.plos.org/plosone/article/file?id=10.1371/journal.pone.0173152
# Resolving journals.plos.org (journals.plos.org)... 35.190.43.188
# Connecting to journals.plos.org (journals.plos.org)|35.190.43.188|:443... connected.
# HTTP request sent, awaiting response... 404 Not Found
# 2023-06-27 10:54:07 ERROR 404: Not Found.
#
# Extracting 7c6dd680030a3111409c45dfc28b1d9feebc25e3
# ***** Problems with ./papers_pdf/7c6dd680030a3111409c45dfc28b1d9feebc25e3.pdf. Ignoring...
# Downloading paper 2ab8533cad8782b015c81a5a2ae8fdad70afecb5: https://ojs.aaai.org/index.php/AAAI/article/download/17777/17584
# --2023-06-27 10:54:07--  https://ojs.aaai.org/index.php/AAAI/article/download/17777/17584
# Resolving ojs.aaai.org (ojs.aaai.org)... 208.70.245.162
# Connecting to ojs.aaai.org (ojs.aaai.org)|208.70.245.162|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1074307 (1.0M) [application/pdf]
# Saving to: ‘./papers_pdf/2ab8533cad8782b015c81a5a2ae8fdad70afecb5.pdf’
#
# ./papers_pdf/2ab853 100%[===================>]   1.02M   312KB/s    in 3.4s
#
# 2023-06-27 10:54:11 (312 KB/s) - ‘./papers_pdf/2ab8533cad8782b015c81a5a2ae8fdad70afecb5.pdf’ saved [1074307/1074307]
#
# Extracting 2ab8533cad8782b015c81a5a2ae8fdad70afecb5
# Downloading paper b2ca0ebd121a06bbfafbfc5fffcb000007cf1565: https://download.atlantis-press.com/article/25862313.pdf
# --2023-06-27 10:54:12--  https://download.atlantis-press.com/article/25862313.pdf
# Resolving download.atlantis-press.com (download.atlantis-press.com)... 136.144.178.116
# Connecting to download.atlantis-press.com (download.atlantis-press.com)|136.144.178.116|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1578072 (1.5M) [application/pdf]
# Saving to: ‘./papers_pdf/b2ca0ebd121a06bbfafbfc5fffcb000007cf1565.pdf’
#
# ./papers_pdf/b2ca0e 100%[===================>]   1.50M  1.19MB/s    in 1.3s
#
# 2023-06-27 10:54:14 (1.19 MB/s) - ‘./papers_pdf/b2ca0ebd121a06bbfafbfc5fffcb000007cf1565.pdf’ saved [1578072/1578072]
#
# Extracting b2ca0ebd121a06bbfafbfc5fffcb000007cf1565
# Downloading paper ab9a2d43b3e7d99a717003f763f96b10e2c16ca1: http://arxiv.org/pdf/1106.0411
# URL transformed to HTTPS due to an HSTS policy
# --2023-06-27 10:54:15--  https://arxiv.org/pdf/1106.0411
# Resolving arxiv.org (arxiv.org)... 128.84.21.199
# Connecting to arxiv.org (arxiv.org)|128.84.21.199|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://arxiv.org/pdf/1106.0411.pdf [following]
# --2023-06-27 10:54:15--  https://arxiv.org/pdf/1106.0411.pdf
# Reusing existing connection to arxiv.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 313152 (306K) [application/pdf]
# Saving to: ‘./papers_pdf/ab9a2d43b3e7d99a717003f763f96b10e2c16ca1.pdf’
#
# ./papers_pdf/ab9a2d 100%[===================>] 305.81K   412KB/s    in 0.7s
#
# 2023-06-27 10:54:17 (412 KB/s) - ‘./papers_pdf/ab9a2d43b3e7d99a717003f763f96b10e2c16ca1.pdf’ saved [313152/313152]
#
# Extracting ab9a2d43b3e7d99a717003f763f96b10e2c16ca1
# Downloading paper 972672719e67bd097954c36da4c2ad7c17246b18: https://doi.org/10.7753/ijcatr0303.1002
# --2023-06-27 10:54:17--  https://doi.org/10.7753/ijcatr0303.1002
# Resolving doi.org (doi.org)... 104.26.8.237, 104.26.9.237, 172.67.72.147, ...
# Connecting to doi.org (doi.org)|104.26.8.237|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: http://www.ijcat.com/archives/volume3/issue3/ijcatr03031002.pdf [following]
# --2023-06-27 10:54:17--  http://www.ijcat.com/archives/volume3/issue3/ijcatr03031002.pdf
# Resolving www.ijcat.com (www.ijcat.com)... 103.76.228.249
# Connecting to www.ijcat.com (www.ijcat.com)|103.76.228.249|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 199440 (195K) [application/pdf]
# Saving to: ‘./papers_pdf/972672719e67bd097954c36da4c2ad7c17246b18.pdf’
#
# ./papers_pdf/972672 100%[===================>] 194.77K   585KB/s    in 0.3s
#
# 2023-06-27 10:54:18 (585 KB/s) - ‘./papers_pdf/972672719e67bd097954c36da4c2ad7c17246b18.pdf’ saved [199440/199440]
#
# Extracting 972672719e67bd097954c36da4c2ad7c17246b18
# Downloading paper 73068d13d6e53876c374ebd4c862ec01351c9f39: https://www.aclweb.org/anthology/2020.emnlp-main.60.pdf
# --2023-06-27 10:54:19--  https://www.aclweb.org/anthology/2020.emnlp-main.60.pdf
# Resolving www.aclweb.org (www.aclweb.org)... 50.87.169.12
# Connecting to www.aclweb.org (www.aclweb.org)|50.87.169.12|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://aclanthology.org/2020.emnlp-main.60.pdf [following]
# --2023-06-27 10:54:20--  https://aclanthology.org/2020.emnlp-main.60.pdf
# Resolving aclanthology.org (aclanthology.org)... 174.138.37.75
# Connecting to aclanthology.org (aclanthology.org)|174.138.37.75|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8319779 (7.9M) [application/pdf]
# Saving to: ‘./papers_pdf/73068d13d6e53876c374ebd4c862ec01351c9f39.pdf’
#
# ./papers_pdf/73068d 100%[===================>]   7.93M  4.47MB/s    in 1.8s
#
# 2023-06-27 10:54:22 (4.47 MB/s) - ‘./papers_pdf/73068d13d6e53876c374ebd4c862ec01351c9f39.pdf’ saved [8319779/8319779]
#
# Extracting 73068d13d6e53876c374ebd4c862ec01351c9f39
# Downloading paper 9c07a128b5b5e4d8edebfc36f384acf0f48296b7: https://kuwaitjournals.org/jer/index.php/JER/article/download/19467/3453
# --2023-06-27 10:54:22--  https://kuwaitjournals.org/jer/index.php/JER/article/download/19467/3453
# Resolving kuwaitjournals.org (kuwaitjournals.org)... 208.70.247.107
# Connecting to kuwaitjournals.org (kuwaitjournals.org)|208.70.247.107|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1020458 (997K) [application/pdf]
# Saving to: ‘./papers_pdf/9c07a128b5b5e4d8edebfc36f384acf0f48296b7.pdf’
#
# ./papers_pdf/9c07a1 100%[===================>] 996.54K  1.20MB/s    in 0.8s
#
# 2023-06-27 10:54:24 (1.20 MB/s) - ‘./papers_pdf/9c07a128b5b5e4d8edebfc36f384acf0f48296b7.pdf’ saved [1020458/1020458]
#
# Extracting 9c07a128b5b5e4d8edebfc36f384acf0f48296b7

# %%
has_text = 0
for key, paper in papers.items():
  has_text += (1 if paper['text'] != '' else 0)
print(f'Extracted {has_text}/{len(papers.keys())}')
# Out:
# Extracted 28/37

# %%
with open(file_papers_contents, 'wb') as f:
  pickle.dump(papers, f)

# %%
# !zip -r papers.zip papers_pdf
# Out:
#   adding: papers_pdf/ (stored 0%)
#   adding: papers_pdf/2c40b968cf53d4a82f6d603253a16f413b82c3e8.pdf (deflated 18%)
#   adding: papers_pdf/20381cd41140b547d54899b69424b69d0de567e0.pdf (deflated 10%)
#   adding: papers_pdf/e7d7dc15e7327d0b9b01d2987c63383c53325d50.pdf (stored 0%)
#   adding: papers_pdf/ab9a2d43b3e7d99a717003f763f96b10e2c16ca1.pdf (deflated 9%)
#   adding: papers_pdf/a246d0d4093c798d300ea96a5645b2aa21c022a0.pdf (stored 0%)
#   adding: papers_pdf/95ee6dbaf9bb4ef6a9808366e552b400ad48dbc0.pdf (deflated 1%)
#   adding: papers_pdf/f38237fa10da8bac34fa84fd63aa3dc254812ff6.pdf (deflated 3%)
#   adding: papers_pdf/9c07a128b5b5e4d8edebfc36f384acf0f48296b7.pdf (deflated 14%)
#   adding: papers_pdf/a5ac8ff1f9a5ae7a9a6650e1908c7f44614b1d23.pdf (deflated 10%)
#   adding: papers_pdf/73068d13d6e53876c374ebd4c862ec01351c9f39.pdf (deflated 2%)
#   adding: papers_pdf/972672719e67bd097954c36da4c2ad7c17246b18.pdf (deflated 15%)
#   adding: papers_pdf/01657e073dbb39d5c0ffeccb85e5b239c0e35ff1.pdf (deflated 19%)
#   adding: papers_pdf/b030ceb178313e4e1d1321119c2460428558a5d0.pdf (deflated 21%)
#   adding: papers_pdf/7c72a2008f94078ce50ac251c6437038bbcf0185.pdf (deflated 12%)
#   adding: papers_pdf/64e63f5b5613de74831bd29bc8983f92be1fc8bc.pdf (deflated 11%)
#   adding: papers_pdf/f44370126c8cd4f1ab0fe2832d3f9a6fa6b6f3cc.pdf (deflated 4%)
#   adding: papers_pdf/af43de01456a26a9a237ceeebb80292fae523ec6.pdf (deflated 10%)
#   adding: papers_pdf/8483632dd1bbab0516f7104a70995d05045615f1.pdf (deflated 22%)
#   adding: papers_pdf/2ab8533cad8782b015c81a5a2ae8fdad70afecb5.pdf (deflated 4%)
#   adding: papers_pdf/09de817e0552bed0cf47f262e8476c87a601109a.pdf (stored 0%)
#   adding: papers_pdf/d018efda7a49c03955f5b62c11d6de5c5725f8bc.pdf (deflated 22%)
#   adding: papers_pdf/0c01ed865fe6793aa526c9adb795736e3b2f2113.pdf (deflated 9%)
#   adding: papers_pdf/3e45b7dbe1f12ea0110fa5bb7609aa90b33c20d9.pdf (deflated 14%)
#   adding: papers_pdf/0767eb5ab61d25920bc4046b3baab6ee5c6d5cfa.pdf (deflated 7%)
#   adding: papers_pdf/f3cc9d54c5bd1672a3dad370897834ac3967b2ff.pdf (deflated 3%)
#   adding: papers_pdf/b2ca0ebd121a06bbfafbfc5fffcb000007cf1565.pdf (deflated 1%)
#   adding: papers_pdf/3ca2499d5b00c21f12b8717e3c25a5d00a0aeb41.pdf (deflated 21%)
#   adding: papers_pdf/e26acb19824738c1ce8364d87b35914393649d31.pdf (deflated 2%)
#   adding: papers_pdf/5624ee3a16da7c77bf9eee491516939acf2862a6.pdf (deflated 51%)
#   adding: papers_pdf/5160254e9dd5d6c0006f113a5784467eedd449e0.pdf (deflated 19%)
#   adding: papers_pdf/09cdc6bcd057e38746d08e2a74d40a6ca9630484.pdf (deflated 3%)
#   adding: papers_pdf/6c318926ec149a5e1a17599e67cc70d85e09a9a0.pdf (deflated 3%)
#   adding: papers_pdf/6e8c87b244faa88c396c78c85568e69ed08d17fe.pdf (stored 0%)

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#!cp papers.zip '/content/drive/My Drive/papers_2015_2023.zip'
